# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.22/02

# %%
# %%cpp
# TFile *results = new TFile("wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root", "update");
# Out:
# Warning in <TClass::Init>: no dictionary for class detectorParams is available

# %%
# %%cpp
# results->cd();
# waveburst->Print();
# Out:
# ******************************************************************************
# *Tree    :waveburst : waveburst                                              *
# *Entries :     4377 : Total =         2509636 bytes  File  Size =    2016372 *
# *        :          : Tree compression factor =   1.20                       *
# ******************************************************************************
# *Br    0 :run       : run/I                                                  *
# *Entries :     4377 : Total  Size=      35950 bytes  File Size  =      25888 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.23     *
# *............................................................................*
# *Br    1 :eventID   : eventID[2]/I                                           *
# *Entries :     4377 : Total  Size=      54244 bytes  File Size  =      23680 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.12     *
# *............................................................................*
# *Br    2 :strain    : strain[2]/D                                            *
# *Entries :     4377 : Total  Size=      89073 bytes  File Size  =      84930 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    3 :phi       : phi[4]/F                                               *
# *Entries :     4377 : Total  Size=      88480 bytes  File Size  =      77489 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.09     *
# *............................................................................*
# *Br    4 :theta     : theta[4]/F                                             *
# *Entries :     4377 : Total  Size=      88870 bytes  File Size  =      78070 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.09     *
# *............................................................................*
# *Br    5 :psi       : psi[2]/F                                               *
# *Entries :     4377 : Total  Size=      53464 bytes  File Size  =      41044 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    6 :iota      : iota[2]/F                                              *
# *Entries :     4377 : Total  Size=      53659 bytes  File Size  =      42339 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.17     *
# *............................................................................*
# *Br    7 :time      : time[6]/D                                              *
# *Entries :     4377 : Total  Size=     228747 bytes  File Size  =     136624 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   1.64     *
# *............................................................................*
# *Br    8 :duration  : duration[3]/F                                          *
# *Entries :     4377 : Total  Size=      71947 bytes  File Size  =      49264 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.38     *
# *............................................................................*
# *Br    9 :frequency : frequency[3]/F                                         *
# *Entries :     4377 : Total  Size=      72142 bytes  File Size  =      56878 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   10 :low       : low[3]/F                                               *
# *Entries :     4377 : Total  Size=      70972 bytes  File Size  =      23289 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.87     *
# *............................................................................*
# *Br   11 :high      : high[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      32477 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.06     *
# *............................................................................*
# *Br   12 :bandwidth : bandwidth[3]/F                                         *
# *Entries :     4377 : Total  Size=      72142 bytes  File Size  =      52077 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.31     *
# *............................................................................*
# *Br   13 :hrss      : hrss[6]/D                                              *
# *Entries :     4377 : Total  Size=     228747 bytes  File Size  =     224546 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   14 :noise     : noise[3]/D                                             *
# *Entries :     4377 : Total  Size=     123894 bytes  File Size  =     119755 *
# *Baskets :      191 : Basket Size=       1024 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   15 :erA       : erA[11]/F                                              *
# *Entries :     4377 : Total  Size=     211038 bytes  File Size  =      96776 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   2.14     *
# *............................................................................*
# *Br   16 :null      : null[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   17 :nill      : nill[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   18 :netcc     : netcc[4]/F                                             *
# *Entries :     4377 : Total  Size=      88870 bytes  File Size  =      83135 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.02     *
# *............................................................................*
# *Br   19 :rho       : rho[2]/F                                               *
# *Entries :     4377 : Total  Size=      53464 bytes  File Size  =      49341 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   20 :gnet      : gnet/F                                                 *
# *Entries :     4377 : Total  Size=      36145 bytes  File Size  =      32024 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   21 :ecor      : ecor/F                                                 *
# *Entries :     4377 : Total  Size=      36145 bytes  File Size  =      32024 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   22 :penalty   : penalty/F                                              *
# *Entries :     4377 : Total  Size=      36730 bytes  File Size  =      32597 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   23 :likelihood : likelihood/F                                          *
# *Entries :     4377 : Total  Size=      37315 bytes  File Size  =      33170 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   24 :factor    : factor/F                                               *
# *Entries :     4377 : Total  Size=      36535 bytes  File Size  =      20528 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.58     *
# *............................................................................*
# *Br   25 :snr       : snr[3]/F                                               *
# *Entries :     4377 : Total  Size=      70972 bytes  File Size  =      66849 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   26 :xSNR      : xSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   27 :sSNR      : sSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   28 :iSNR      : iSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   29 :oSNR      : oSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   30 :ioSNR     : ioSNR[3]/F                                             *
# *Entries :     4377 : Total  Size=      71362 bytes  File Size  =      67231 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0

# %%
# %%cpp
# TCanvas *ct = new TCanvas( "ct", "ct", 600, 600 );
# ct->cd();
# waveburst->Draw("oSNR");
# ct->Draw();

# %%
# %%cpp
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path +    "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TH1F* hist_rho = new TH1F( "hist_rho", "hist_rho", 100, 0, 150 );
# TH2F* hist_rho_time[num_det];
#
# char cuts[4096];
# char name[1028];
# char  sel[1028];
#
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
#
# for( int jj=0; jj<num_det; jj++ ){ // ciclo sui rivelatori
#     cx[jj]->cd();
#     sprintf( cuts, "rho<250" );
#     merge_tree->Draw( "rho>>hist_rho", cuts);
#
#     sprintf( name, "hist_rho_time_%i", jj );
#     hist_rho_time[jj] = new TH2F( name,  name, 1000, 1.1645e+9,
#                                       1.1651*1e+9,  100, 0,   250);
#     sprintf( sel, "rho:time[%i]>>hist_rho_time_%i", jj, jj );
#     merge_tree->Draw( sel, cuts );
#     cx[jj]->Draw("COL");
# }
#
# int            entr = merge_tree->GetEntries();
# const auto det_cons =		 2 * 	 num_det;
# double time[det_cons];
# float rho;
#
# merge_tree->SetBranchAddress( "time", &time );
# merge_tree->SetBranchAddress(  "rho", &rho  );
#
# for( int i=0; i < entr; i++ ){
#     merge_tree->GetEntry( i );
# //    cout << time[0] << "\t" << rho << endl;
# }
#
# TCanvas* Cplot = new TCanvas( "plot", "plot", 600,
#                                400,    600, 400);
# Cplot->Divide( 2, 1 );
# Cplot->cd(        1 );
#
# hist_rho->Draw();
# Cplot->cd(2);
# hist_rho_time[0]->Draw();
# char out[1024];
#
# Cplot->Draw();
#
#
# //sprintf( out, "%s/test_rho.png", path_save.Data() );
# //Cplot->SaveAs( out );
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0

# %%
# %%cpp
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TH1F* hist_oSNR = new TH1F( "hist_oSNR", "hist_oSNR", 75, 0, 260 );
# TH2F* hist_oSNR_time[num_det];
#
# char cuts[4096];
# char name[1028];
# char  sel[1028];
#
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
#
# for( int jj=0; jj<num_det; jj++ ){ // ciclo sui rivelatori
#     cx[jj]->cd();
#     sprintf( cuts, "oSNR<250" );
#     merge_tree->Draw( "oSNR>>hist_oSNR", cuts);
#
#     sprintf( name, "hist_oSNR_time_%i", jj );
#     hist_oSNR_time[jj] = new TH2F( name,  name, 500, 1.1645e+9,
#                                       1.1651*1e+9,  75, 0,   260);
#     sprintf( sel, "oSNR:time[%i]>>hist_oSNR_time_%i", jj, jj );
#     merge_tree->Draw( sel, cuts );
#     cx[jj]->Draw("COL");
# }
#
# int            entr = merge_tree->GetEntries();
# const auto det_cons =		 2 * 	 num_det;
# double time[det_cons];
# float oSNR;
#
# merge_tree->SetBranchAddress( "time", &time );
# merge_tree->SetBranchAddress( "oSNR", &oSNR  );
#
# for( int i=0; i < entr; i++ ){
#     merge_tree->GetEntry( i );
# //    cout << time[0] << "\t" << oSNR << endl;
# }
#
# TCanvas* Cplot = new TCanvas( "plot", "plot", 600,
#                                400,    600, 400);
# Cplot->Divide( 2, 1 );
# Cplot->cd(        1 );
#
# hist_oSNR->Draw();
# Cplot->cd(2);
# hist_oSNR_time[0]->Draw();
# char out[1024];
#
# Cplot->Draw();
#
#
# //sprintf( out, "%s/test_oSNR.png", path_save.Data() );
# //Cplot->SaveAs( out );
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: plot

# %%
# %%cpp
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TH1F* hist_iSNR = new TH1F( "hist_iSNR", "hist_iSNR", 75, 0, 260 );
# TH2F* hist_iSNR_time[num_det];
#
# char cuts[4096];
# char name[1028];
# char  sel[1028];
# /*
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
# */
# TCanvas* cx = new TCanvas( "c", "c", 500, 500 );
# cx->cd();
# for( int jj=0; jj<num_det; jj++ ){ // ciclo sui rivelatori
# //    cx[jj]->cd();
#     sprintf( cuts, "iSNR<250" );
#     merge_tree->Draw( "iSNR>>hist_iSNR", cuts);
#
#     sprintf( name, "hist_iSNR_time_%i", jj );
#     hist_iSNR_time[jj] = new TH2F( name,  name, 500, 1.1645e+9,
#                                       1.1651*1e+9,  75, 0,   260);
#     sprintf( sel, "iSNR:time[%i]>>hist_iSNR_time_%i", jj, jj );
#     merge_tree->Draw( sel, cuts );
#
# //    cx[jj]->Draw("COLZ");
#     cx->Draw();
# }
#
# int            entr = merge_tree->GetEntries();
# const auto det_cons =		 2 * 	 num_det;
# //double time[det_cons];
# double time;
# float iSNR;
#
# merge_tree->SetBranchAddress( "time", &time );
# merge_tree->SetBranchAddress( "iSNR", &iSNR  );
#
# for( int i=0; i < entr; i++ ){
#     merge_tree->GetEntry( i );
# //    cout << time[0] << "\t" << time[1] << "\t" << time[5] << endl;
# }
#
# TCanvas* Cplot = new TCanvas( "plot", "plot", 600,
#                                400,    600, 400);
# Cplot->Divide( 2, 1 );
# Cplot->cd(        1 );
#
# hist_iSNR->Draw();
# Cplot->cd(2);
# hist_iSNR_time[0]->Draw();
# char out[1024];
#
# Cplot->Draw();
#
#
# //sprintf( out, "%s/test_iSNR.png", path_save.Data() );
# //Cplot->SaveAs( out );
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: plot

# %%
# %%cpp
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TH1F* hist_ioSNR = new TH1F( "hist_ioSNR", "hist_ioSNR", 75, 0, 260 );
# TH2F* hist_ioSNR_time[num_det];
#
# char cuts[4096];
# char name[1028];
# char  sel[1028];
#
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
#
# for( int jj=0; jj<num_det; jj++ ){ // ciclo sui rivelatori
#     cx[jj]->cd();
#     sprintf( cuts, "ioSNR<250" );
#     merge_tree->Draw( "ioSNR>>hist_ioSNR", cuts);
#
#     sprintf( name, "hist_ioSNR_time_%i", jj );
#     hist_ioSNR_time[jj] = new TH2F( name,  name, 500, 1.1645e+9,
#                                       1.1651*1e+9,  75, 0,   260);
#     sprintf( sel, "ioSNR:time[%i]>>hist_ioSNR_time_%i", jj, jj );
#     merge_tree->Draw( sel, cuts );
#     cx[jj]->Draw("COL");
# }
#
# int            entr = merge_tree->GetEntries();
# const auto det_cons =		 2 * 	 num_det;
# double time[det_cons];
# float ioSNR;
#
# merge_tree->SetBranchAddress( "time", &time );
# merge_tree->SetBranchAddress( "ioSNR", &ioSNR  );
#
# for( int i=0; i < entr; i++ ){
#     merge_tree->GetEntry( i );
# //    cout << time[0] << "\t" << ioSNR << endl;
# }
#
# TCanvas* Cplot = new TCanvas( "plot", "plot", 600,
#                                400,    600, 400);
# Cplot->Divide( 2, 1 );
# Cplot->cd(        1 );
#
# hist_ioSNR->Draw();
# Cplot->cd(2);
# hist_ioSNR_time[0]->Draw();
# char out[1024];
#
# Cplot->Draw();
#
#
# //sprintf( out, "%s/test_ioSNR.png", path_save.Data() );
# //Cplot->SaveAs( out );
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: plot

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# int numDistances = 5;
# int nBinDx = 10;
# int nBinDy = 10;
# float factor, ioSNR, iSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
#
# /*
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
# */
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance_" + std::to_string( i  + 1 );
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName, hName,
#                          nBinDx, 0, 250,
#                          nBinDy, 0, 250  ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR[j-1]->Fill( sqrt(iSNR), sqrt(ioSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# //ct9->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
#     VioSNR[i-1]->Draw("SAME COLZ");
# //    VioSNR[i-1]->SetLineWidth(4);
# }
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(   "iSNR"     );
#     VioSNR[i]->GetYaxis()->SetTitle(  "ioSNR"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
#
# ct9->Draw();
# //ct9->Print(("ioSNRDistributionFactor.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0

# %%
# %%cpp
#
# TH2F *hframeSNR = new TH2F("hframeSNR","hframeSNR",400,0,5.5,400,0,620);
# hframeSNR->Draw();
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TCanvas *kp1bs= new TCanvas("kp1bs", "kp1bs", 600,600);
# kp1bs->cd();
# merge_tree->Draw("sqrt(ioSNR):sqrt(iSNR)");
# kp1bs->Draw();
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle->SetOptStat(0);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, iSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR    );
#
# std::vector <TH1F*> ViSNR;
# ViSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             ViSNR[j-1]->Fill( sqrt(iSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# ct9->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ViSNR[i-1]->Draw("SAME");
#     ViSNR[i-1]->SetLineWidth(4);
# }
#
# ViSNR[0]->SetLineColor(kBlue);
# ViSNR[1]->SetLineColor(kRed);
# ViSNR[2]->SetLineColor(kGreen);
# ViSNR[3]->SetLineColor(kBlack);
# ViSNR[4]->SetLineColor(kViolet);
#
# ViSNR[0]->            SetTitle(  "iSNR"  );
# ViSNR[0]->GetXaxis()->SetTitle(  "iSNR"  );
# ViSNR[0]->GetYaxis()->SetTitle( "counts" );
#
# ViSNR[0]->GetXaxis()->CenterTitle();
# ViSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legend = new TLegend(0.75,0.6,0.925,0.925);
# legend->SetHeader("Distances", "C");
#
#
# const char* legName;
# std:string lName;
# for( int i = 0; i < numDistances; ++i ){
#     lName   = d[i] + " kPc";
#     legName = lName.c_str();
#     legend->AddEntry( ViSNR[i], legName, "l" );
# }
#
# legend->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("report/iSNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/iSNRDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(0);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, oSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR    );
#
# std::vector <TH1F*> VoSNR;
# VoSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VoSNR[j-1]->Fill( sqrt(oSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# ct9->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     VoSNR[i-1]->Draw("SAME");
#     VoSNR[i-1]->SetLineWidth(4);
# }
#
# VoSNR[0]->SetLineColor(kBlue);
# VoSNR[1]->SetLineColor(kRed);
# VoSNR[2]->SetLineColor(kGreen);
# VoSNR[3]->SetLineColor(kBlack);
# VoSNR[4]->SetLineColor(kViolet);
#
# VoSNR[0]->            SetTitle(  "oSNR"  );
# VoSNR[0]->GetXaxis()->SetTitle(  "oSNR"  );
# VoSNR[0]->GetYaxis()->SetTitle( "counts" );
#
# VoSNR[0]->GetXaxis()->CenterTitle();
# VoSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legend = new TLegend(0.75,0.6,0.925,0.925);
# legend->SetHeader("Distances", "C");
#
#
# const char* legName;
# std:string lName;
# for( int i = 0; i < numDistances; ++i ){
#     lName   = d[i] + " kPc";
#     legName = lName.c_str();
#     legend->AddEntry( VoSNR[i], legName, "l" );
# }
#
# legend->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("report/oSNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/oSNRDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinD = 150;
# float iSNR, oSNR;
#
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
#
# TH1F* ViSNR = new TH1F( "Injected", "Injected", nBinD, 0, 250 );
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     ViSNR->Fill( sqrt(iSNR) );
# }
#
# TH1F* VoSNR = new TH1F( "Outputted", "Outputted", nBinD, 0, 250 );
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     VoSNR->Fill( sqrt(oSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1080, 1920 );
# ct9->Divide(1,2);
# ct9->cd(1);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
#
# ViSNR->Draw("SAME");
# ViSNR->SetLineWidth(4);
# ViSNR->SetLineColor(kBlue);
# ViSNR->            SetTitle( "Injected" );
# ViSNR->GetXaxis()->SetTitle(   "iSNR"   );
# ViSNR->GetYaxis()->SetTitle(  "counts"  );
# ViSNR->GetXaxis()->CenterTitle();
# ViSNR->GetYaxis()->CenterTitle();
#
# ct9->cd(2);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# VoSNR->Draw("SAME");
# VoSNR->SetLineWidth(4);
# VoSNR->SetLineColor(kBlue);
# VoSNR->            SetTitle( "Outputted" );
# VoSNR->GetXaxis()->SetTitle(   "oSNR"    );
# VoSNR->GetYaxis()->SetTitle(  "counts"   );
# VoSNR->GetXaxis()->CenterTitle();
# VoSNR->GetYaxis()->CenterTitle();
#
#
# ct9->Draw();
# ct9->Print(("report/SNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/SNRDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, oSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
#
# std::vector <TH1F*> VoSNR;
# VoSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VoSNR[j-1]->Fill( sqrt(oSNR) );
# }
#
# std::vector <TH1F*> ViSNR;
# ViSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             ViSNR[j-1]->Fill( sqrt(iSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1080, 1920 );
# ct9->Divide(1,2);
# ct9->cd(1);
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ViSNR[i-1]->Draw("SAME");
#     ViSNR[i-1]->SetLineWidth(4);
# }
#
# ViSNR[0]->SetLineColor(kBlue);
# ViSNR[1]->SetLineColor(kRed);
# ViSNR[2]->SetLineColor(kGreen);
# ViSNR[3]->SetLineColor(kBlack);
# ViSNR[4]->SetLineColor(kViolet);
#
# ViSNR[0]->            SetTitle( "Injected" );
# ViSNR[0]->GetXaxis()->SetTitle(   "iSNR"   );
# ViSNR[0]->GetYaxis()->SetTitle(  "counts"  );
#
# ViSNR[0]->GetXaxis()->CenterTitle();
# ViSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendiSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendiSNR->SetHeader("Distances", "C");
# legendiSNR->SetNColumns(2);
#
# const char* legNameiSNR;
# string lNameiSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameiSNR   = d[i] + " kPc";
#     legNameiSNR = lNameiSNR.c_str();
#     legendiSNR->AddEntry( ViSNR[i], legNameiSNR, "l" );
# }
#
# legendiSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
#
# ct9->cd(2);
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     VoSNR[i-1]->Draw("SAME");
#     VoSNR[i-1]->SetLineWidth(4);
# }
#
# gStyle -> SetOptStat(0);
#
# VoSNR[0]->SetLineColor(kBlue);
# VoSNR[1]->SetLineColor(kRed);
# VoSNR[2]->SetLineColor(kGreen);
# VoSNR[3]->SetLineColor(kBlack);
# VoSNR[4]->SetLineColor(kViolet);
#
# VoSNR[0]->            SetTitle( "Outputted" );
# VoSNR[0]->GetXaxis()->SetTitle(   "oSNR"    );
# VoSNR[0]->GetYaxis()->SetTitle(  "counts"   );
#
# VoSNR[0]->GetXaxis()->CenterTitle();
# VoSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendoSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendoSNR->SetHeader("Distances", "C");
# legendoSNR->SetNColumns(2);
#
#
# const char* legNameoSNR;
# string lNameoSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameoSNR   = d[i] + " kPc";
#     legNameoSNR = lNameoSNR.c_str();
#     legendoSNR->AddEntry( VoSNR[i], legNameoSNR, "l" );
# }
#
# legendoSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("report/SNRDistributionFactors.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TFile::Append>: Replacing existing TH1: distance1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance4 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance5 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/SNRDistributionFactors.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 16;
# int nBinDy = 50;
# float iSNR, oSNR, factor;
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
#
# TH2F* VioSNR = new TH2F( "Residual", "Residual",
#                          nBinDx,  0,        400,
#                          nBinDy,  0,        1.6 );
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     VioSNR->Fill( sqrt(                 iSNR ),
#                   sqrt( iSNR * oSNR ) / iSNR );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.25);
# gStyle->SetStatY(0.25);
# VioSNR->Draw("COLZ");
# VioSNR->SetLineWidth(4);
# VioSNR->SetLineColor(kBlue);
# VioSNR->            SetTitle( "" );
# VioSNR->GetXaxis()->SetTitle(   "iSNR"   );
# VioSNR->GetYaxis()->SetTitle(  "iSNR*oSNR/iSNR^2"  );
# VioSNR->GetXaxis()->CenterTitle();
# VioSNR->GetYaxis()->CenterTitle();
#
# ct9->Draw();
# //ct9->Print(("i*oSNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 16;
# int nBinDy = 50;
# float ioSNR, iSNR, oSNR, factor;
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
#
# TH2F* VioSNR = new TH2F( "VioSNR", "VioSNR",
#                          nBinDx,  0,        400,
#                          nBinDy,  0,          2 );
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     VioSNR->Fill(                     sqrt( iSNR ),
#                   abs(iSNR + oSNR - 2*ioSNR) / iSNR );
# //    std::cout <<  (iSNR + oSNR - 2*ioSNR) / iSNR << std::endl;
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.85);
# gStyle->SetStatY(0.95);
# VioSNR->Draw("COLZ");
# VioSNR->SetLineWidth(4);
# VioSNR->SetLineColor(kBlue);
# VioSNR->            SetTitle( "" );
# VioSNR->GetXaxis()->SetTitle(   "iSNR"   );
# VioSNR->GetYaxis()->SetTitle(  "|iSNR-oSNR|/iSNR"  );
# VioSNR->GetXaxis()->CenterTitle();
# VioSNR->GetYaxis()->CenterTitle();
#
# ct9->Draw();
# //ct9->Print(("i-oSNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 16;
# int nBinDy = 75;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
#
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName, hName,
#                               nBinDx, 0, 400,
#                               nBinDy, 0, 1.5));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR[j-1]->Fill(                          sqrt( iSNR ),
#                                abs( iSNR + oSNR - 2*ioSNR ) /  sqrt(iSNR*oSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
#
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
#     VioSNR[i-1]->Draw("SAME COLZ");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(   "sqrt(iSNR)"     );
#     VioSNR[i]->GetYaxis()->SetTitle(  "(iSNR+oSNR-2ioSNR)/iSNR"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# //ct9->Print(("report/i-oSNRDistributionFactor.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9

# %%
"""%%cpp

#include <string>
#include <vector>
gStyle -> SetOptStat(1111);
TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";

TString merge_file_name = path + namefile;
TString       path_save = path + "report/dump";

TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );

//int nBinDx = 16;
int nBinDx = 50;
int nBinDy = 50;
float iSNR, oSNR;
float ioSNR[3];
const char* hName;
std::string histname;
float likelihood, factor;

merge_tree->SetBranchAddress(       "iSNR", &iSNR       );
merge_tree->SetBranchAddress(       "oSNR", &oSNR       );
merge_tree->SetBranchAddress(      "ioSNR", &ioSNR      );
merge_tree->SetBranchAddress(     "factor", &factor     );
merge_tree->SetBranchAddress( "likelihood", &likelihood );

std::vector <TH2F*> VioSNR;
VioSNR.reserve( numDistances );
for( int i = 0; i < numDistances; ++i ){
    histname = "distance" + std::to_string(i+1);
    hName = histname.c_str();
    VioSNR.push_back(new TH2F( hName, hName, 
                              nBinDx, 0, 150000,
                              nBinDy, 0,   1));
}

float iosnr;
int entr = merge_tree->GetEntries();
for( int i = 0; i < entr; ++i ){
    merge_tree->GetEntry( i );
//    std::cout << (iSNR + oSNR - 2*ioSNR)/iSNR << std::endl;
//    std::cout << likelihood << std::endl;
    for( int j = 1; j < 6; ++j )
        if( factor == j )
            VioSNR[j-1]->Fill(                    likelihood,
                             (iSNR + oSNR - 2*ioSNR)/iSNR);
}

TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
ct9->Divide(3,2);
gPad->SetGrid();
gStyle->SetGridStyle(7);
gStyle->SetGridWidth(1);
gStyle->SetStatX(0.75);
gStyle->SetStatY(0.75);



for( int i = 1; i < 6; ++i ){
    ct9->cd(i);
    VioSNR[i-1]->Draw("SAME COLZ");
}


for(int i = 0; i < numDistances; ++i){
    VioSNR[i]->GetXaxis()->SetTitle(   "likelihood"     );
    VioSNR[i]->GetYaxis()->SetTitle(  "|iSNR-oSNR|/iSNR"   );
    VioSNR[i]->GetXaxis()->CenterTitle();
    VioSNR[i]->GetYaxis()->CenterTitle();    
}
ct9->Draw();
//ct9->Print(("i-oSNRDistributionFactor.pdf"));
"""
# Out:
# '%%cpp\n\n#include <string>\n#include <vector>\ngStyle -> SetOptStat(1111);\nTString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";\nTString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";\n\nTString merge_file_name = path + namefile;\nTString       path_save = path + "report/dump";\n\nTFile*  filemerge = new TFile( merge_file_name.Data(), "update" );\nTTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );\n\n//int nBinDx = 16;\nint nBinDx = 50;\nint nBinDy = 50;\nfloat iSNR, oSNR;\nfloat ioSNR[3];\nconst char* hName;\nstd::string histname;\nfloat likelihood, factor;\n\nmerge_tree->SetBranchAddress(       "iSNR", &iSNR       );\nmerge_tree->SetBranchAddress(       "oSNR", &oSNR       );\nmerge_tree->SetBranchAddress(      "ioSNR", &ioSNR      );\nmerge_tree->SetBranchAddress(     "factor", &factor     );\nmerge_tree->SetBranchAddress( "likelihood", &likelihood );\n\nstd::vector <TH2F*> VioSNR;\nVioSNR.reserve( numDistances );\nfor( int i = 0; i < numDistances; ++i ){\n    histname = "distance" + std::to_string(i+1);\n    hName = histname.c_str();\n    VioSNR.push_back(new TH2F( hName, hName, \n                              nBinDx, 0, 150000,\n                              nBinDy, 0,   1));\n}\n\nfloat iosnr;\nint entr = merge_tree->GetEntries();\nfor( int i = 0; i < entr; ++i ){\n    merge_tree->GetEntry( i );\n//    std::cout << (iSNR + oSNR - 2*ioSNR)/iSNR << std::endl;\n//    std::cout << likelihood << std::endl;\n    for( int j = 1; j < 6; ++j )\n        if( factor == j )\n            VioSNR[j-1]->Fill(                    likelihood,\n                             (iSNR + oSNR - 2*ioSNR)/iSNR);\n}\n\nTCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );\nct9->Divide(3,2);\ngPad->SetGrid();\ngStyle->SetGridStyle(7);\ngStyle->SetGridWidth(1);\ngStyle->SetStatX(0.75);\ngStyle->SetStatY(0.75);\n\n\n\nfor( int i = 1; i < 6; ++i ){\n    ct9->cd(i);\n    VioSNR[i-1]->Draw("SAME COLZ");\n}\n\n\nfor(int i = 0; i < numDistances; ++i){\n    VioSNR[i]->GetXaxis()->SetTitle(   "likelihood"     );\n    VioSNR[i]->GetYaxis()->SetTitle(  "|iSNR-oSNR|/iSNR"   );\n    VioSNR[i]->GetXaxis()->CenterTitle();\n    VioSNR[i]->GetYaxis()->CenterTitle();    \n}\nct9->Draw();\n//ct9->Print(("i-oSNRDistributionFactor.pdf"));\n'

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle->SetOptStat(0);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, likelihood;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress(     "factor", &factor     );
# merge_tree->SetBranchAddress( "likelihood", &likelihood );
#
# std::vector <TH1F*> Vlikelihood;
# Vlikelihood.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     Vlikelihood.push_back(new TH1F( hName, hName, nBinD, 0, 150000 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             Vlikelihood[j-1]->Fill( likelihood );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# ct9->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     Vlikelihood[i-1]->Draw("SAME");
#     Vlikelihood[i-1]->SetLineWidth(4);
# }
#
# Vlikelihood[0]->SetLineColor(kBlue);
# Vlikelihood[1]->SetLineColor(kRed);
# Vlikelihood[2]->SetLineColor(kGreen);
# Vlikelihood[3]->SetLineColor(kBlack);
# Vlikelihood[4]->SetLineColor(kViolet);
#
# Vlikelihood[0]->            SetTitle( "likelihood" );
# Vlikelihood[0]->GetXaxis()->SetTitle( "likelihood" );
# Vlikelihood[0]->GetYaxis()->SetTitle(   "counts"   );
#
# Vlikelihood[0]->GetXaxis()->CenterTitle();
# Vlikelihood[0]->GetYaxis()->CenterTitle();
# Vlikelihood[0]->SetMinimum(1);
#
# TLegend *legend = new TLegend(0.75,0.6,0.925,0.925);
# legend->SetHeader("Distances", "C");
# const char* legName;
# std:string lName;
# for( int i = 0; i < numDistances; ++i ){
#     lName   = d[i] + " kPc";
#     legName = lName.c_str();
#     legend->AddEntry( Vlikelihood[i], legName, "l" );
# }
#
# legend->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
# //gPad->SetLogx();
#
# ct9->Draw();
# ct9->Print(("report/likelihoodDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/likelihoodDistribution.pdf has been created

# %%
"""%%cpp

#include <string>
#include <vector>
gStyle -> SetOptStat(1111);
TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";

TString merge_file_name = path + namefile;
TString       path_save = path + "report/dump";

TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );

int nBinDx = 16;
int nBinDy = 50;
float iSNR, oSNR;
const char* hName;
std::string histname;

merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
merge_tree->SetBranchAddress( "factor", &factor );

std::vector <TH2F*> VioSNR;
VioSNR.reserve( numDistances );
for( int i = 0; i < numDistances; ++i ){
    histname = "distance" + std::to_string(i+1);
    hName = histname.c_str();
    VioSNR.push_back(new TH2F( hName, hName, 
                              nBinDx, 0, 400,
                              nBinDy, 0,   1));
}

int entr = merge_tree->GetEntries();
for( int i = 0; i < entr; ++i ){
    merge_tree->GetEntry( i );
//    std::cout << (iSNR + oSNR - 2*ioSNR)/iSNR << std::endl;
    for( int j = 1; j < 6; ++j )
        if( factor == j )
            VioSNR[j-1]->Fill(                sqrt(  iSNR   ),
                             (iSNR + oSNR - 2*ioSNR)/iSNR);
}

TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
ct9->Divide(3,2);
gPad->SetGrid();
gStyle->SetGridStyle(7);
gStyle->SetGridWidth(1);
gStyle->SetStatX(0.5);
gStyle->SetStatY(0.5);



for( int i = 1; i < 6; ++i ){
    ct9->cd(i);
    VioSNR[i-1]->Draw("SAME COLZ");
}


for(int i = 0; i < numDistances; ++i){
    VioSNR[i]->GetXaxis()->SetTitle(   "iSNR"     );
    VioSNR[i]->GetYaxis()->SetTitle(  "|iSNR-oSNR|/iSNR"   );
    VioSNR[i]->GetXaxis()->CenterTitle();
    VioSNR[i]->GetYaxis()->CenterTitle();    
}
ct9->Draw();
//ct9->Print(("i-oSNRDistributionFactor.pdf"));


std::vector <TH1F*> VoSNR;
VoSNR.reserve( numDistances );
for( int i = 0; i < numDistances; ++i ){
    histname = "distance" + std::to_string(i+1);
    hName = histname.c_str();
    VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
}

for( int i = 0; i < entr; ++i ){
    merge_tree->GetEntry( i );
    for( int j = 1; j < 6; ++j )
        if( factor == j )
            VoSNR[j-1]->Fill( sqrt(oSNR) );
}

TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1920, 1080 );
ct10->cd();
ct10->SetGrid();
for( int i = 1; i < 6; ++i ){
    VoSNR[i-1]->Draw("SAME");
    VoSNR[i-1]->SetLineWidth(4);
}

VoSNR[0]->SetLineColor(kBlue);
VoSNR[1]->SetLineColor(kRed);
VoSNR[2]->SetLineColor(kGreen);
VoSNR[3]->SetLineColor(kBlack);
VoSNR[4]->SetLineColor(kViolet);

VoSNR[0]->            SetTitle(  "oSNR"  );
VoSNR[0]->GetXaxis()->SetTitle(  "oSNR"  );
VoSNR[0]->GetYaxis()->SetTitle( "counts" );

VoSNR[0]->GetXaxis()->CenterTitle();
VoSNR[0]->GetYaxis()->CenterTitle();   
gStyle->SetGridStyle(7);
gStyle->SetGridWidth(1);
gPad->SetLogy();
    
ct10->Draw();


std::vector <TH1F*> ViSNR;
ViSNR.reserve( numDistances );
for( int i = 0; i < numDistances; ++i ){
    histname = "distance" + std::to_string(i+1);
    hName = histname.c_str();
    ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
}

for( int i = 0; i < entr; ++i ){
    merge_tree->GetEntry( i );
    for( int j = 1; j < 6; ++j )
        if( factor == j )
            ViSNR[j-1]->Fill( sqrt(iSNR) );
}

TCanvas  *ct11 = new TCanvas( "ct11", "ct11", 1920, 1080 );
ct11->cd();
ct11->SetGrid();
for( int i = 1; i < 6; ++i ){
    ViSNR[i-1]->Draw("SAME");
    ViSNR[i-1]->SetLineWidth(4);
}

ViSNR[0]->SetLineColor(kBlue);
ViSNR[1]->SetLineColor(kRed);
ViSNR[2]->SetLineColor(kGreen);
ViSNR[3]->SetLineColor(kBlack);
ViSNR[4]->SetLineColor(kViolet);

ViSNR[0]->            SetTitle(  "iSNR"  );
ViSNR[0]->GetXaxis()->SetTitle(  "iSNR"  );
ViSNR[0]->GetYaxis()->SetTitle( "counts" );

ViSNR[0]->GetXaxis()->CenterTitle();
ViSNR[0]->GetYaxis()->CenterTitle();    

gStyle->SetGridStyle(7);
gStyle->SetGridWidth(1);
gPad->SetLogy();
    
ct11->Draw();


std::vector <TH1F*> VioSNR1;
VioSNR1.reserve( numDistances );
for( int i = 0; i < numDistances; ++i ){
    histname = "distance" + std::to_string(i+1);
    hName = histname.c_str();
    VioSNR1.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
}

for( int i = 0; i < entr; ++i ){
    merge_tree->GetEntry( i );
    for( int j = 1; j < 6; ++j )
        if( factor == j )
            VioSNR1[j-1]->Fill( sqrt(ioSNR) );
}

TCanvas  *ct12 = new TCanvas( "ct12", "ct12", 1920, 1080 );
ct12->cd();
ct12->SetGrid();
for( int i = 1; i < 6; ++i ){
    VioSNR1[i-1]->Draw("SAME");
    VioSNR1[i-1]->SetLineWidth(4);
}

VioSNR1[0]->SetLineColor(kBlue);
VioSNR1[1]->SetLineColor(kRed);
VioSNR1[2]->SetLineColor(kGreen);
VioSNR1[3]->SetLineColor(kBlack);
VioSNR1[4]->SetLineColor(kViolet);

VioSNR1[0]->            SetTitle(  "ioSNR"  );
VioSNR1[0]->GetXaxis()->SetTitle(  "ioSNR"  );
VioSNR1[0]->GetYaxis()->SetTitle( "counts" );

VioSNR1[0]->GetXaxis()->CenterTitle();
VioSNR1[0]->GetYaxis()->CenterTitle();    

gStyle->SetGridStyle(7);
gStyle->SetGridWidth(1);
gPad->SetLogy();
    
ct12->Draw();"""
# Out:
# '%%cpp\n\n#include <string>\n#include <vector>\ngStyle -> SetOptStat(1111);\nTString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";\nTString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";\n\nTString merge_file_name = path + namefile;\nTString       path_save = path + "report/dump";\n\nTFile*  filemerge = new TFile( merge_file_name.Data(), "update" );\nTTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );\n\nint nBinDx = 16;\nint nBinDy = 50;\nfloat iSNR, oSNR;\nconst char* hName;\nstd::string histname;\n\nmerge_tree->SetBranchAddress(   "iSNR", &iSNR   );\nmerge_tree->SetBranchAddress(   "oSNR", &oSNR   );\nmerge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );\nmerge_tree->SetBranchAddress( "factor", &factor );\n\nstd::vector <TH2F*> VioSNR;\nVioSNR.reserve( numDistances );\nfor( int i = 0; i < numDistances; ++i ){\n    histname = "distance" + std::to_string(i+1);\n    hName = histname.c_str();\n    VioSNR.push_back(new TH2F( hName, hName, \n                              nBinDx, 0, 400,\n                              nBinDy, 0,   1));\n}\n\nint entr = merge_tree->GetEntries();\nfor( int i = 0; i < entr; ++i ){\n    merge_tree->GetEntry( i );\n//    std::cout << (iSNR + oSNR - 2*ioSNR)/iSNR << std::endl;\n    for( int j = 1; j < 6; ++j )\n        if( factor == j )\n            VioSNR[j-1]->Fill(                sqrt(  iSNR   ),\n                             (iSNR + oSNR - 2*ioSNR)/iSNR);\n}\n\nTCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );\nct9->Divide(3,2);\ngPad->SetGrid();\ngStyle->SetGridStyle(7);\ngStyle->SetGridWidth(1);\ngStyle->SetStatX(0.5);\ngStyle->SetStatY(0.5);\n\n\n\nfor( int i = 1; i < 6; ++i ){\n    ct9->cd(i);\n    VioSNR[i-1]->Draw("SAME COLZ");\n}\n\n\nfor(int i = 0; i < numDistances; ++i){\n    VioSNR[i]->GetXaxis()->SetTitle(   "iSNR"     );\n    VioSNR[i]->GetYaxis()->SetTitle(  "|iSNR-oSNR|/iSNR"   );\n    VioSNR[i]->GetXaxis()->CenterTitle();\n    VioSNR[i]->GetYaxis()->CenterTitle();    \n}\nct9->Draw();\n//ct9->Print(("i-oSNRDistributionFactor.pdf"));\n\n\nstd::vector <TH1F*> VoSNR;\nVoSNR.reserve( numDistances );\nfor( int i = 0; i < numDistances; ++i ){\n    histname = "distance" + std::to_string(i+1);\n    hName = histname.c_str();\n    VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));\n}\n\nfor( int i = 0; i < entr; ++i ){\n    merge_tree->GetEntry( i );\n    for( int j = 1; j < 6; ++j )\n        if( factor == j )\n            VoSNR[j-1]->Fill( sqrt(oSNR) );\n}\n\nTCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1920, 1080 );\nct10->cd();\nct10->SetGrid();\nfor( int i = 1; i < 6; ++i ){\n    VoSNR[i-1]->Draw("SAME");\n    VoSNR[i-1]->SetLineWidth(4);\n}\n\nVoSNR[0]->SetLineColor(kBlue);\nVoSNR[1]->SetLineColor(kRed);\nVoSNR[2]->SetLineColor(kGreen);\nVoSNR[3]->SetLineColor(kBlack);\nVoSNR[4]->SetLineColor(kViolet);\n\nVoSNR[0]->            SetTitle(  "oSNR"  );\nVoSNR[0]->GetXaxis()->SetTitle(  "oSNR"  );\nVoSNR[0]->GetYaxis()->SetTitle( "counts" );\n\nVoSNR[0]->GetXaxis()->CenterTitle();\nVoSNR[0]->GetYaxis()->CenterTitle();   \ngStyle->SetGridStyle(7);\ngStyle->SetGridWidth(1);\ngPad->SetLogy();\n    \nct10->Draw();\n\n\nstd::vector <TH1F*> ViSNR;\nViSNR.reserve( numDistances );\nfor( int i = 0; i < numDistances; ++i ){\n    histname = "distance" + std::to_string(i+1);\n    hName = histname.c_str();\n    ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));\n}\n\nfor( int i = 0; i < entr; ++i ){\n    merge_tree->GetEntry( i );\n    for( int j = 1; j < 6; ++j )\n        if( factor == j )\n            ViSNR[j-1]->Fill( sqrt(iSNR) );\n}\n\nTCanvas  *ct11 = new TCanvas( "ct11", "ct11", 1920, 1080 );\nct11->cd();\nct11->SetGrid();\nfor( int i = 1; i < 6; ++i ){\n    ViSNR[i-1]->Draw("SAME");\n    ViSNR[i-1]->SetLineWidth(4);\n}\n\nViSNR[0]->SetLineColor(kBlue);\nViSNR[1]->SetLineColor(kRed);\nViSNR[2]->SetLineColor(kGreen);\nViSNR[3]->SetLineColor(kBlack);\nViSNR[4]->SetLineColor(kViolet);\n\nViSNR[0]->            SetTitle(  "iSNR"  );\nViSNR[0]- ...

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 16;
# int nBinDy = 75;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
#
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# TH2F* Voverlap = new TH2F( "Voverlap", "Voverlap",
#                            nBinDx,  0,        250,
#                            nBinDy,  0,          1 );
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "Distance = " +  d[i] + " kPc";
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName,   hName,
#                                nBinDx, 0, 250,
#                                nBinDy, 0,   1));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     Voverlap->Fill(          sqrt(   iSNR    ),
#                     ioSNR /  sqrt( iSNR*oSNR ));
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR[j-1]->Fill(         sqrt(   iSNR    ),
#                                ioSNR / sqrt( iSNR*oSNR ));
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.3);
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     VioSNR[i-1]->Draw("SAME COLZ");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle( "Injected SNR" );
#     VioSNR[i]->GetYaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("report/overlapDistributionFactorCOLZ.pdf"));
#
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1200, 1000 );
# ct10->cd();
# //gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.3);
# Voverlap->Draw("COLZ");
# Voverlap->SetLineWidth(4);
# Voverlap->SetLineColor(kBlue);
# Voverlap->            SetTitle( "Overlap distribution" );
# Voverlap->GetXaxis()->SetTitle( "Injected SNR" );
# Voverlap->GetYaxis()->SetTitle(    "overlap"   );
# Voverlap->GetXaxis()->CenterTitle();
# Voverlap->GetYaxis()->CenterTitle();
#
# ct10->Draw();
# ct10->Print(("report/overlapDistributionCOLZ.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/overlapDistributionFactorCOLZ.pdf has been created
# Info in <TCanvas::Print>: pdf file report/overlapDistributionCOLZ.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# //int nBinDx = 16;
# int nBinDx = 50;
# int nBinDy = 50;
# float iSNR, oSNR;
# const char* hName;
# std::string histname;
# float likelihood, factor;
#
# merge_tree->SetBranchAddress(       "iSNR", &iSNR       );
# merge_tree->SetBranchAddress(       "oSNR", &oSNR       );
# merge_tree->SetBranchAddress(      "ioSNR", &ioSNR      );
# merge_tree->SetBranchAddress(     "factor", &factor     );
# merge_tree->SetBranchAddress( "likelihood", &likelihood );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "Distance = " +  d[i] + " kPc";
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName, hName,
#                               nBinDx, 0, 200000,
#                               nBinDy, 0,  4000));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR[j-1]->Fill(            likelihood,
#                                iSNR + oSNR - 2*ioSNR );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.25);
# gStyle->SetStatY(0.95);
#
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
#     VioSNR[i-1]->Draw("SAME COLZ");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(   "likelihood"     );
#     VioSNR[i]->GetYaxis()->SetTitle(  "residual energy"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("report/ResidualEnergyDistributionFactor.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/ResidualEnergyDistributionFactor.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(111111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 4*16;
# int nBinDy = 4*75;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
# double time[6];
#
# merge_tree->SetBranchAddress(   "time", &time   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# TH2F* Voverlap = new TH2F( "Voverlap", "Voverlap",
#                            nBinDx,  0,        250,
#                            nBinDy,  0,          1 );
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "Distance = " +  d[i] + " kPc";
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName,   hName,
#                                nBinDx, 0, 250,
#                                nBinDy, 0,   1));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[0] - time[3] ) < 5 ){
#         Voverlap->Fill(          sqrt(   iSNR    ),
#                         ioSNR /  sqrt( iSNR*oSNR ));
#         for( int j = 1; j < 6; ++j )
#             if( factor == j )
#                 VioSNR[j-1]->Fill(         sqrt(   iSNR    ),
#                                    ioSNR / sqrt( iSNR*oSNR ));
#     }
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.4);
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     VioSNR[i-1]->SetMarkerSize(10);
#     VioSNR[i-1]->Draw("");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle( "Injected SNR" );
#     VioSNR[i]->GetYaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("report/overlapDistributionFactor.pdf"));
#
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1200, 1000 );
# ct10->cd();
# //gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.4);
# Voverlap->Draw("");
# Voverlap->SetLineWidth(4);
# Voverlap->SetLineColor(kBlue);
# Voverlap->            SetTitle( "Overlap distribution" );
# Voverlap->GetXaxis()->SetTitle( "Injected SNR" );
# Voverlap->GetYaxis()->SetTitle(    "overlap"   );
# Voverlap->GetXaxis()->CenterTitle();
# Voverlap->GetYaxis()->CenterTitle();
#
# ct10->Draw();
# ct10->Print(("report/overlapDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/overlapDistributionFactor.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct10
# Info in <TCanvas::Print>: pdf file report/overlapDistribution.pdf has been created

# %%
# %%cpp
# TFile *APR4 = new TFile("wave_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1_cl.root", "update");
# APR4->cd();
# waveburst->Print();
# Out:
# ******************************************************************************
# *Tree    :waveburst : waveburst                                              *
# *Entries :     4377 : Total =         2533320 bytes  File  Size =    2016372 *
# *        :          : Tree compression factor =   1.20                       *
# ******************************************************************************
# *Br    0 :run       : run/I                                                  *
# *Entries :     4377 : Total  Size=      36714 bytes  File Size  =      25888 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.23     *
# *............................................................................*
# *Br    1 :eventID   : eventID[2]/I                                           *
# *Entries :     4377 : Total  Size=      55008 bytes  File Size  =      23680 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.12     *
# *............................................................................*
# *Br    2 :strain    : strain[2]/D                                            *
# *Entries :     4377 : Total  Size=      89837 bytes  File Size  =      84930 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    3 :phi       : phi[4]/F                                               *
# *Entries :     4377 : Total  Size=      89244 bytes  File Size  =      77489 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.09     *
# *............................................................................*
# *Br    4 :theta     : theta[4]/F                                             *
# *Entries :     4377 : Total  Size=      89634 bytes  File Size  =      78070 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.09     *
# *............................................................................*
# *Br    5 :psi       : psi[2]/F                                               *
# *Entries :     4377 : Total  Size=      54228 bytes  File Size  =      41044 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    6 :iota      : iota[2]/F                                              *
# *Entries :     4377 : Total  Size=      54423 bytes  File Size  =      42339 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.17     *
# *............................................................................*
# *Br    7 :time      : time[6]/D                                              *
# *Entries :     4377 : Total  Size=     229511 bytes  File Size  =     136624 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   1.64     *
# *............................................................................*
# *Br    8 :duration  : duration[3]/F                                          *
# *Entries :     4377 : Total  Size=      72711 bytes  File Size  =      49264 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.38     *
# *............................................................................*
# *Br    9 :frequency : frequency[3]/F                                         *
# *Entries :     4377 : Total  Size=      72906 bytes  File Size  =      56878 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   10 :low       : low[3]/F                                               *
# *Entries :     4377 : Total  Size=      71736 bytes  File Size  =      23289 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.87     *
# *............................................................................*
# *Br   11 :high      : high[3]/F                                              *
# *Entries :     4377 : Total  Size=      71931 bytes  File Size  =      32477 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.06     *
# *............................................................................*
# *Br   12 :bandwidth : bandwidth[3]/F                                         *
# *Entries :     4377 : Total  Size=      72906 bytes  File Size  =      52077 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.31     *
# *............................................................................*
# *Br   13 :hrss      : hrss[6]/D                                              *
# *Entries :     4377 : Total  Size=     229511 bytes  File Size  =     224546 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   14 :noise     : noise[3]/D                                             *
# *Entries :     4377 : Total  Size=     124658 bytes  File Size  =     119755 *
# *Baskets :      191 : Basket Size=       1024 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   15 :erA       : erA[11]/F                                              *
# *Entries :     4377 : Total  Size=     211802 bytes  File Size  =      96776 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   2.14     *
# *............................................................................*
# *Br   16 :null      : null[3]/F                                              *
# *Entries :     4377 : Total  Size=      71931 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   17 :nill      : nill[3]/F                                              *
# *Entries :     4377 : Total  Size=      71931 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   18 :netcc     : netcc[4]/F                                             *
# *Entries :     4377 : Total  Size=      89634 bytes  File Size  =      83135 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.02     *
# *............................................................................*
# *Br   19 :rho       : rho[2]/F                                               *
# *Entries :     4377 : Total  Size=      54228 bytes  File Size  =      49341 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   20 :gnet      : gnet/F                                                 *
# *Entries :     4377 : Total  Size=      36909 bytes  File Size  =      32024 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   21 :ecor      : ecor/F                                                 *
# *Entries :     4377 : Total  Size=      36909 bytes  File Size  =      32024 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   22 :penalty   : penalty/F                                              *
# *Entries :     4377 : Total  Size=      37494 bytes  File Size  =      32597 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   23 :likelihood : likelihood/F                                          *
# *Entries :     4377 : Total  Size=      38079 bytes  File Size  =      33170 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   24 :factor    : factor/F                                               *
# *Entries :     4377 : Total  Size=      37299 bytes  File Size  =      20528 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.58     *
# *............................................................................*
# *Br   25 :snr       : snr[3]/F                                               *
# *Entries :     4377 : Total  Size=      71736 bytes  File Size  =      66849 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   26 :xSNR      : xSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71931 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   27 :sSNR      : sSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71931 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   28 :iSNR      : iSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71931 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   29 :oSNR      : oSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71931 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   30 :ioSNR     : ioSNR[3]/F                                             *
# *Entries :     4377 : Total  Size=      72126 bytes  File Size  =      67231 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(111111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1_cl.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 4*16;
# int nBinDy = 4*75;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
# double time[6];
#
#
# merge_tree->SetBranchAddress(   "time", &time   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# TH2F* Voverlap = new TH2F( "Voverlap", "Voverlap",
#                            nBinDx,  0,        250,
#                            nBinDy,  0,          1 );
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "Distance = " +  d[i] + " kPc";
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName,   hName,
#                                nBinDx, 0, 250,
#                                nBinDy, 0,   1));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[1] - time[4] ) < 5 ){
# //        std::cout << time[0] - time[3] << std::endl;
#         Voverlap->Fill(          sqrt(   iSNR    ),
#                         ioSNR /  sqrt( iSNR*oSNR ));
#         for( int j = 1; j < 6; ++j )
#             if( factor == j )
#                 VioSNR[j-1]->Fill(         sqrt(   iSNR    ),
#                                    ioSNR / sqrt( iSNR*oSNR ));
#     }
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.4);
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     VioSNR[i-1]->SetMarkerSize(10);
#     VioSNR[i-1]->Draw("");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle( "Injected SNR" );
#     VioSNR[i]->GetYaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("report/APR4overlapDistributionFactor.pdf"));
#
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1200, 1000 );
# ct10->cd();
# //gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.4);
# Voverlap->Draw("");
# Voverlap->SetLineWidth(4);
# Voverlap->SetLineColor(kBlue);
# Voverlap->            SetTitle( "Overlap distribution" );
# Voverlap->GetXaxis()->SetTitle( "Injected SNR" );
# Voverlap->GetYaxis()->SetTitle(    "overlap"   );
# Voverlap->GetXaxis()->CenterTitle();
# Voverlap->GetYaxis()->CenterTitle();
#
# ct10->Draw();
# ct10->Print(("report/APR4_overlapDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 16197 not found at 102
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/APR4overlapDistributionFactor.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct10
# Info in <TCanvas::Print>: pdf file report/APR4_overlapDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1_cl.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, oSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
#
# std::vector <TH1F*> VoSNR;
# VoSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 300 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VoSNR[j-1]->Fill( sqrt(oSNR) );
# }
#
# std::vector <TH1F*> ViSNR;
# ViSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 300 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             ViSNR[j-1]->Fill( sqrt(iSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1080, 1920 );
# ct9->Divide(1,2);
# ct9->cd(1);
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ViSNR[i-1]->Draw("SAME");
#     ViSNR[i-1]->SetLineWidth(4);
# }
#
# ViSNR[0]->SetLineColor(kBlue);
# ViSNR[1]->SetLineColor(kRed);
# ViSNR[2]->SetLineColor(kGreen);
# ViSNR[3]->SetLineColor(kBlack);
# ViSNR[4]->SetLineColor(kViolet);
#
# ViSNR[0]->            SetTitle( "Injected" );
# ViSNR[0]->GetXaxis()->SetTitle(   "iSNR"   );
# ViSNR[0]->GetYaxis()->SetTitle(  "counts"  );
#
# ViSNR[0]->GetXaxis()->CenterTitle();
# ViSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendiSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendiSNR->SetHeader("Distances", "C");
# legendiSNR->SetNColumns(2);
#
# const char* legNameiSNR;
# string lNameiSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameiSNR   = d[i] + " kPc";
#     legNameiSNR = lNameiSNR.c_str();
#     legendiSNR->AddEntry( ViSNR[i], legNameiSNR, "l" );
# }
#
# legendiSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
#
# ct9->cd(2);
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     VoSNR[i-1]->Draw("SAME");
#     VoSNR[i-1]->SetLineWidth(4);
# }
#
# gStyle -> SetOptStat(0);
#
# VoSNR[0]->SetLineColor(kBlue);
# VoSNR[1]->SetLineColor(kRed);
# VoSNR[2]->SetLineColor(kGreen);
# VoSNR[3]->SetLineColor(kBlack);
# VoSNR[4]->SetLineColor(kViolet);
#
# VoSNR[0]->            SetTitle( "Outputted" );
# VoSNR[0]->GetXaxis()->SetTitle(   "oSNR"    );
# VoSNR[0]->GetYaxis()->SetTitle(  "counts"   );
#
# VoSNR[0]->GetXaxis()->CenterTitle();
# VoSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendoSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendoSNR->SetHeader("Distances", "C");
# legendoSNR->SetNColumns(2);
#
#
# const char* legNameoSNR;
# string lNameoSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameoSNR   = d[i] + " kPc";
#     legNameoSNR = lNameoSNR.c_str();
#     legendoSNR->AddEntry( VoSNR[i], legNameoSNR, "l" );
# }
#
# legendoSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("report/APR4_SNRDistributionFactors.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 16197 not found at 102
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TFile::Append>: Replacing existing TH1: distance1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance4 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance5 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/APR4_SNRDistributionFactors.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1_cl.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 10*16;
# int nBinDy = 4*75;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
# double time[6];
#
# merge_tree->SetBranchAddress(   "time", &time   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# TH2F* Voverlap = new TH2F( "Voverlap", "Voverlap",
#                            nBinDx,  0,        250,
#                            nBinDy,  0,          1 );
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "Distance = " +  d[i] + " kPc";
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName,   hName,
#                                nBinDx, 0, 250,
#                                nBinDy, 0,   1));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[1] - time[4] ) < 5 ){
# //        std::cout << time[0] - time[3] << std::endl;
#         Voverlap->Fill(          sqrt(   iSNR    ),
#                         ioSNR /  sqrt( iSNR*oSNR ));
#         for( int j = 1; j < 6; ++j )
#             if( factor == j )
#                 VioSNR[j-1]->Fill(         sqrt(   iSNR    ),
#                                    ioSNR / sqrt( iSNR*oSNR ));
#     }
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.3);
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     VioSNR[i-1]->Draw("SAME COLZ");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle( "Injected SNR" );
#     VioSNR[i]->GetYaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("report/APR4overlapDistributionFactorCOLZ.pdf"));
#
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1200, 1000 );
# ct10->cd();
# //gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.3);
# Voverlap->Draw("COLZ");
# Voverlap->SetLineWidth(4);
# Voverlap->SetLineColor(kBlue);
# Voverlap->            SetTitle( "Overlap distribution" );
# Voverlap->GetXaxis()->SetTitle( "Injected SNR" );
# Voverlap->GetYaxis()->SetTitle(    "overlap"   );
# Voverlap->GetXaxis()->CenterTitle();
# Voverlap->GetYaxis()->CenterTitle();
#
# ct10->Draw();
# ct10->Print(("report/APR4_overlapDistributionCOLZ.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 16197 not found at 102
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/APR4overlapDistributionFactorCOLZ.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct10
# Info in <TCanvas::Print>: pdf file report/APR4_overlapDistributionCOLZ.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(111111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# const int nBinDx = 10;
# int nBinDy = 50;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
# double time[6];
# double    SNR[nBinDx];
# double errSNR[nBinDx]; //HA ERRORE L'SNR RICOSTRUITO?
# double    mea[nBinDx];
# double    rms[nBinDx];
# int larg = 25;
#
# merge_tree->SetBranchAddress(   "time", &time   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH1F*> V;
# V.reserve( nBinDx );
#
#
# for( int i = 0; i < nBinDx; ++i ){
#     SNR[i] = ( i * larg + ( i + 1 ) * larg ) / 2;
#     histname = "SNR " +  to_string( (int)SNR[i] );
#     hName = histname.c_str();
# //    V.push_back(new TH1F( hName,   hName,
# //                          10, i * larg, ( i + 1 ) * larg ));
#     V.push_back(new TH1F( hName,   hName,
#                             nBinDy, 0.5+0.5*(1-exp(-0.4*(i-0.2))), 1 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[0] - time[3] ) < 5 )
#         for( int j = 0; j < nBinDx; ++j )
#             if( sqrt(oSNR) >=    j     * larg &&
#                 sqrt(oSNR) < ( j + 1 ) * larg )
#                 V[j]->Fill( ioSNR / sqrt( iSNR*oSNR ));
# }
#
# for( int i = 0; i < nBinDx; ++i ){
#     mea[i]    = V[i]->GetMean();
#     rms[i]    = V[i]->GetStdDev();
#     errSNR[i] = 1 / sqrt( SNR[i] );
# }
#
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(5,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
#
#
# for( int i = 1; i < 11; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     V[i-1]->Draw("");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
# }
# gStyle->SetStatX(0.25);
# gStyle->SetStatY(0.925);
# ct9->Draw("");
# ct9->Print(("report/overlapDistributions.pdf"));
#
#
# TGraphErrors *overlaps = new TGraphErrors( nBinDx,
#                                               SNR,
#                                               mea,
#                                            errSNR,
#                                               rms );
#
# overlaps->GetXaxis()->SetTitle( "Outputted SNR" );
# overlaps->GetXaxis()->CenterTitle();
# overlaps->GetYaxis()->SetTitle( "averge overlap" );
# overlaps->GetYaxis()->CenterTitle();
# overlaps->SetTitle("Overlaps distribution");
# overlaps->SetMarkerStyle(104);
#
#
# //TF1 *fitter = new TF1( "fitter", "[0] + ")
#
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1200, 1000 );
# ct10->cd();
# overlaps->Draw("AP");
# ct10->Draw();
# ct10->Print(("report/Overlaps_Graph.pdf"))
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/overlapDistributions.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct10
# Info in <TCanvas::Print>: pdf file report/Overlaps_Graph.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(0);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 4*16;
# int nBinDy = 4*75;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
# double time[6];
#
# merge_tree->SetBranchAddress(   "time", &time   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# TH2F* Voverlap = new TH2F( "Voverlap", "Voverlap",
#                            nBinDx,  0,        250,
#                            nBinDy,  0,          1 );
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "Distance = " +  d[i] + " kPc";
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName,   hName,
#                                nBinDx, 0, 250,
#                                nBinDy, 0.4,   1));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[0] - time[3] ) < 5 ){
#         Voverlap->Fill(          sqrt(   iSNR    ),
#                         ioSNR /  sqrt( iSNR*oSNR ));
#         for( int j = 1; j < 6; ++j )
#             if( factor == j )
#                 VioSNR[j-1]->Fill(         sqrt(   iSNR    ),
#                                    ioSNR / sqrt( iSNR*oSNR ));
#     }
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.4);
#
#
# VioSNR[0]->SetMarkerColor(kBlue);
# VioSNR[1]->SetMarkerColor(kRed);
# VioSNR[2]->SetMarkerColor(kGreen);
# VioSNR[3]->SetMarkerColor(kBlack);
# VioSNR[4]->SetMarkerColor(kViolet);
#
# for( int i = 1; i < 6; ++i ){
# //    gPad->SetGrid();
#     VioSNR[i-1]->SetMarkerStyle(20);
#     VioSNR[i-1]->SetMarkerSize(1);
#     VioSNR[i-1]->Draw("SAME");
# }
#
# VioSNR[0]->SetTitle("Overlaps distribution");
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle( "Injected SNR" );
#     VioSNR[i]->GetYaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
#
# TLegend *legendoSNR = new TLegend(0.725,0.05,0.95,0.225);
# legendoSNR->SetHeader("Distances", "C");
# legendoSNR->SetNColumns(2);
#
#
# const char* legNameoSNR;
# string lNameoSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameoSNR   = d[i] + " kPc";
#     legNameoSNR = lNameoSNR.c_str();
#     legendoSNR->AddEntry( VioSNR[i], legNameoSNR, "p" );
# }
#
# legendoSNR->Draw("SAME");
#
# ct9->Draw();
# ct9->Print(("report/overlapDistributionFactorColors.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/overlapDistributionFactorColors.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1_cl.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 10*16;
# int nBinDy = 4*75;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
# double time[6];
# int eventID, run;
#
# merge_tree->SetBranchAddress( "eventID", &eventID );
# merge_tree->SetBranchAddress(    "run", &run    );
# merge_tree->SetBranchAddress(    "time", &time    );
# merge_tree->SetBranchAddress(    "iSNR", &iSNR    );
# merge_tree->SetBranchAddress(    "oSNR", &oSNR    );
# merge_tree->SetBranchAddress(   "ioSNR", &ioSNR   );
# merge_tree->SetBranchAddress(  "factor", &factor  );
#
# std::ofstream write( "eventi.csv" );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# TH2F* Voverlap = new TH2F( "Voverlap", "Voverlap",
#                            nBinDx,  20,        90,
#                            nBinDy,  0,         0.14 );
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "Distance = " +  d[i] + " kPc";
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName,   hName,
#                                nBinDx, 20,  90,
#                                nBinDy, 0, 0.14));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[1] - time[4] ) < 5 ){
# //        std::cout << time[0] - time[3] << std::endl;
#         Voverlap->Fill(          sqrt(   iSNR    ),
#                         ioSNR /  sqrt( iSNR*oSNR ));
#         for( int j = 1; j < 6; ++j ){
#             if( factor == j )
#                 VioSNR[j-1]->Fill(         sqrt(   iSNR    ),
#                                    ioSNR / sqrt( iSNR*oSNR ));
#         }
#     }
# }
#
#
# write << "contatore,eventID,run" << std::endl;
# int cont = 0;
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( sqrt(iSNR) > 20 && sqrt(iSNR) < 90 &&
#         ioSNR / sqrt( iSNR*oSNR ) < 0.12 )
#         write << cont << "," << eventID << "," << run << std::endl;
#     ++cont;
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.3);
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     VioSNR[i-1]->SetMarkerStyle(20);
#     VioSNR[i-1]->Draw("SAME");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle( "Injected SNR" );
#     VioSNR[i]->GetYaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("report/APR4overlapDistributionFactorCOLZ.pdf"));
#
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1200, 1000 );
# ct10->cd();
# //gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.3);
# Voverlap->SetMarkerStyle(20);
# Voverlap->Draw("");
# Voverlap->SetLineWidth(4);
# Voverlap->SetLineColor(kBlue);
# Voverlap->            SetTitle( "Overlap distribution" );
# Voverlap->GetXaxis()->SetTitle( "Injected SNR" );
# Voverlap->GetYaxis()->SetTitle(    "overlap"   );
# Voverlap->GetXaxis()->CenterTitle();
# Voverlap->GetYaxis()->CenterTitle();
#
# ct10->Draw();
# ct10->Print(("report/APR4_overlapDistributionCOLZ.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 16197 not found at 102
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/APR4overlapDistributionFactorCOLZ.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct10
# Info in <TCanvas::Print>: pdf file report/APR4_overlapDistributionCOLZ.pdf has been created

# %%
"""%%cpp

#include <string>
#include <vector>
gStyle -> SetOptStat(1111);
TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
TString namemdc  = "mdc_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1.root";
TString namewave = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";

TString mdc_file_name  = path +  namemdc;
TString wave_file_name = path + namewave;
TString     path_save = path + "report/dump";

TFile*  mdc_file  = new TFile(  mdc_file_name.Data(), "update" );
TTree*  mdc_tree  =   ( TTree* )    mdc_file->Get(       "mdc" );
TFile*  wave_file = new TFile( wave_file_name.Data(), "update" );
TTree*  wave_tree =   ( TTree* )   wave_file->Get( "waveburst" );

mdc_tree->Print();
wave_tree->Print();

"""
# Out:
# '%%cpp\n\n#include <string>\n#include <vector>\ngStyle -> SetOptStat(1111);\nTString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";\nTString namemdc  = "mdc_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1.root";\nTString namewave = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";\n\nTString mdc_file_name  = path +  namemdc;\nTString wave_file_name = path + namewave;\nTString     path_save = path + "report/dump";\n\nTFile*  mdc_file  = new TFile(  mdc_file_name.Data(), "update" );\nTTree*  mdc_tree  =   ( TTree* )    mdc_file->Get(       "mdc" );\nTFile*  wave_file = new TFile( wave_file_name.Data(), "update" );\nTTree*  wave_tree =   ( TTree* )   wave_file->Get( "waveburst" );\n\nmdc_tree->Print();\nwave_tree->Print();\n\n'

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# gStyle->SetOptStat(0);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "mdc_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "mdc" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, snr;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(    "snr", &snr    );
#
# std::vector <TH1F*> Vsnr;
# Vsnr.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     Vsnr.push_back(new TH1F( hName, hName, nBinD, 0, 300 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             Vsnr[j-1]->Fill( snr );
# }
#
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     Vsnr[i-1]->Draw("SAME");
#     Vsnr[i-1]->SetLineWidth(4);
# }
#
# Vsnr[0]->SetLineColor(kBlue);
# Vsnr[1]->SetLineColor(kRed);
# Vsnr[2]->SetLineColor(kGreen);
# Vsnr[3]->SetLineColor(kBlack);
# Vsnr[4]->SetLineColor(kViolet);
#
# Vsnr[0]->            SetTitle( "Injected" );
# Vsnr[0]->GetXaxis()->SetTitle(   "iSNR"   );
# Vsnr[0]->GetYaxis()->SetTitle(  "counts"  );
#
# Vsnr[0]->GetXaxis()->CenterTitle();
# Vsnr[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendiSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendiSNR->SetHeader("Distances", "C");
# legendiSNR->SetNColumns(2);
#
# const char* legNameiSNR;
# string lNameiSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameiSNR   = d[i] + " kPc";
#     legNameiSNR = lNameiSNR.c_str();
#     legendiSNR->AddEntry( ViSNR[i], legNameiSNR, "l" );
# }
#
# legendiSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
#
# ct9->Draw();
# //ct9->Print(("report/APR4_SNRDistributionFactors.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 17239 not found at 137
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "mdc_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "mdc" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, snr;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(    "snr", &snr    );
#
# std::vector <TH1F*> Vsnr;
# Vsnr.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     Vsnr.push_back(new TH1F( hName, hName, nBinD, 0, 300 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             Vsnr[j-1]->Fill( snr );
# }
#
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# gPad->SetGrid();
# /*
# for( int i = 1; i < 6; ++i ){
#     Vsnr[i-1]->Draw("SAME");
#     Vsnr[i-1]->SetLineWidth(4);
# }
#
# */
# Vsnr[2]->Draw("SAME");
# Vsnr[2]->SetLineWidth(4);
#
# //Vsnr[0]->SetLineColor(kBlue);
# //Vsnr[1]->SetLineColor(kRed);
# Vsnr[2]->SetLineColor(kGreen);
# //Vsnr[3]->SetLineColor(kBlack);
# //Vsnr[4]->SetLineColor(kViolet);
#
# Vsnr[2]->            SetTitle( "Injected" );
# Vsnr[2]->GetXaxis()->SetTitle(   "snr"   );
# Vsnr[2]->GetYaxis()->SetTitle(  "counts"  );
#
# Vsnr[2]->GetXaxis()->CenterTitle();
# Vsnr[2]->GetYaxis()->CenterTitle();
#
# /*TLegend *legendiSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendiSNR->SetHeader("Distances", "C");
# legendiSNR->SetNColumns(2);
#
# const char* legNameiSNR;
# string lNameiSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameiSNR   = d[i] + " kPc";
#     legNameiSNR = lNameiSNR.c_str();
#     legendiSNR->AddEntry( ViSNR[i], legNameiSNR, "l" );
# }
#
# legendiSNR->Draw("SAME");
# */
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
#
# ct9->Draw();
# ct9->Print(("in.png"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 17239 not found at 137
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: png file in.png has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1_cl.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, oSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
#
# std::vector <TH1F*> VoSNR;
# VoSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 300 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VoSNR[j-1]->Fill( sqrt(oSNR) );
# }
#
# std::vector <TH1F*> ViSNR;
# ViSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 300 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             ViSNR[j-1]->Fill( sqrt(iSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1080, 1920 );
# ct9->Divide(1,2);
# ct9->cd(1);
# gPad->SetGrid();
# /*
# for( int i = 1; i < 6; ++i ){
#     ViSNR[i-1]->Draw("SAME");
#     ViSNR[i-1]->SetLineWidth(4);
# }
# */
#
# ViSNR[2]->Draw("SAME");
# ViSNR[2]->SetLineWidth(4);
# //ViSNR[0]->SetLineColor(kBlue);
# //ViSNR[1]->SetLineColor(kRed);
# ViSNR[2]->SetLineColor(kGreen);
# //ViSNR[3]->SetLineColor(kBlack);
# //ViSNR[4]->SetLineColor(kViolet);
#
# ViSNR[2]->            SetTitle( "Injected" );
# ViSNR[2]->GetXaxis()->SetTitle(   "iSNR"   );
# ViSNR[2]->GetYaxis()->SetTitle(  "counts"  );
#
# ViSNR[2]->GetXaxis()->CenterTitle();
# ViSNR[2]->GetYaxis()->CenterTitle();
# /*
# TLegend *legendiSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendiSNR->SetHeader("Distances", "C");
# legendiSNR->SetNColumns(2);
#
# const char* legNameiSNR;
# string lNameiSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameiSNR   = d[i] + " kPc";
#     legNameiSNR = lNameiSNR.c_str();
#     legendiSNR->AddEntry( ViSNR[i], legNameiSNR, "l" );
# }
#
# legendiSNR->Draw("SAME");
# */
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
#
# ct9->cd(2);
# gPad->SetGrid();
# /*
# for( int i = 1; i < 6; ++i ){
#     VoSNR[i-1]->Draw("SAME");
#     VoSNR[i-1]->SetLineWidth(4);
# }
# */
#
# VoSNR[2]->Draw("SAME");
# VoSNR[2]->SetLineWidth(4);
# gStyle -> SetOptStat(111111);
#
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.75);
# //VoSNR[0]->SetLineColor(kBlue);
# //VoSNR[1]->SetLineColor(kRed);
# VoSNR[2]->SetLineColor(kGreen);
# //VoSNR[3]->SetLineColor(kBlack);
# //VoSNR[4]->SetLineColor(kViolet);
#
# VoSNR[2]->            SetTitle( "Outputted" );
# VoSNR[2]->GetXaxis()->SetTitle(   "oSNR"    );
# VoSNR[2]->GetYaxis()->SetTitle(  "counts"   );
#
# VoSNR[2]->GetXaxis()->CenterTitle();
# VoSNR[2]->GetYaxis()->CenterTitle();
#     /*
# TLegend *legendoSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendoSNR->SetHeader("Distances", "C");
# legendoSNR->SetNColumns(2);
#
#
# const char* legNameoSNR;
# string lNameoSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameoSNR   = d[i] + " kPc";
#     legNameoSNR = lNameoSNR.c_str();
#     legendoSNR->AddEntry( VoSNR[i], legNameoSNR, "l" );
# }
#
# legendoSNR->Draw("SAME");
# */
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("out.png"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 16197 not found at 102
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TFile::Append>: Replacing existing TH1: distance1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance4 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance5 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: png file out.png has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(111111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# const int nBinDx = 20;
# int nBinDy = 50;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
# double time[6];
# double    SNR[nBinDx];
# double errSNR[nBinDx]; //HA ERRORE L'SNR RICOSTRUITO?
# double    mea[nBinDx];
# double    rms[nBinDx];
# double    err[nBinDx];
# int larg = 15;
#
# merge_tree->SetBranchAddress(   "time", &time   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH1F*> V;
# V.reserve( nBinDx );
#
#
# for( int i = 0; i < nBinDx; ++i ){
#     SNR[i] = ( i * larg + ( i + 1 ) * larg ) / 2;
#     histname = "SNR " +  to_string( (int)SNR[i] );
#     hName = histname.c_str();
#     V.push_back(new TH1F( hName,   hName,
#                           nBinDy, 0.5, 1 ));
# //    V.push_back(new TH1F( hName,   hName,
# //                            nBinDy, 0.5+0.5*(1-exp(-0.4*(i-0.2))), 1 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[0] - time[3] ) < 5 )
#         for( int j = 0; j < nBinDx; ++j )
#             if( sqrt(oSNR) >=    j     * larg &&
#                 sqrt(oSNR) < ( j + 1 ) * larg )
#                 V[j]->Fill( ioSNR / sqrt( iSNR*oSNR ));
# }
#
# for( int i = 0; i < nBinDx; ++i ){
#     mea[i]    = V[i]->GetMean();
#     rms[i]    = V[i]->GetStdDev();
#     err[i]    = V[i]->GetMeanError();
#     errSNR[i] = 1 / sqrt( SNR[i] );
# }
#
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(5,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
#
#
# for( int i = 1; i < 11; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     V[i-1]->Draw("");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
# }
# gStyle->SetStatX(0.25);
# gStyle->SetStatY(0.925);
# ct9->Draw("");
# //ct9->Print(("report/overlapDistributions.pdf"));
#
#
# TGraphErrors *overlaps = new TGraphErrors( nBinDx,
#                                               SNR,
#                                               mea,
#                                            errSNR,
#                                               rms );
#
# overlaps->GetXaxis()->SetTitle( "Outputted SNR" );
# overlaps->GetXaxis()->CenterTitle();
# overlaps->GetYaxis()->SetTitle( "averge overlap" );
# overlaps->GetYaxis()->CenterTitle();
# overlaps->SetTitle("Overlaps distribution");
# overlaps->SetMarkerStyle(104);
#
#
# TF1 *fitter = new TF1( "fitter", "x/(x+[0])", 0, 250 );
# overlaps->Fit(fitter);
#
# gStyle -> SetOptFit(0);
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1200, 1000 );
# ct10->cd();
# overlaps->Draw("AP");
# ct10->Draw();
# ct10->Print(("report/Overlaps_Graph_Fitted.png"));
# Out:
#  FCN=0.699069 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=3.41051e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.30475e+00   2.01171e-01   1.27670e-04  -4.10544e-03
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct10
# Info in <TCanvas::Print>: png file report/Overlaps_Graph_Fitted.png has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(111111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# const int nBinDx = 20;
# int nBinDy = 50;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
# double time[6];
# double    SNR[nBinDx];
# double errSNR[nBinDx]; //HA ERRORE L'SNR RICOSTRUITO?
# double    mea[nBinDx];
# double    rms[nBinDx];
# double    err[nBinDx];
# int larg = 15;
#
# merge_tree->SetBranchAddress(   "time", &time   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH1F*> V;
# V.reserve( nBinDx );
#
#
# for( int i = 0; i < nBinDx; ++i ){
#     SNR[i] = ( i * larg + ( i + 1 ) * larg ) / 2;
#     histname = "SNR " +  to_string( (int)SNR[i] );
#     hName = histname.c_str();
#     V.push_back(new TH1F( hName,   hName,
#                           nBinDy, 0.5, 1 ));
# //    V.push_back(new TH1F( hName,   hName,
# //                            nBinDy, 0.5+0.5*(1-exp(-0.4*(i-0.2))), 1 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[0] - time[3] ) < 5 )
#         for( int j = 0; j < nBinDx; ++j )
#             if( sqrt(oSNR) >=    j     * larg &&
#                 sqrt(oSNR) < ( j + 1 ) * larg )
#                 V[j]->Fill( ioSNR / sqrt( iSNR*oSNR ));
# }
#
# for( int i = 0; i < nBinDx; ++i ){
#     mea[i]    = V[i]->GetMean();
#     rms[i]    = V[i]->GetStdDev();
#     err[i]    = V[i]->GetMeanError();
#     errSNR[i] = 1 / sqrt( SNR[i] );
# }
#
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(5,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
#
#
# for( int i = 1; i < 11; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     V[i-1]->Draw("");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
# }
# gStyle->SetStatX(0.25);
# gStyle->SetStatY(0.925);
# ct9->Draw("");
# //ct9->Print(("report/overlapDistributions.pdf"));
#
#
# TGraphErrors *overlaps = new TGraphErrors( nBinDx,
#                                               SNR,
#                                               mea,
#                                            errSNR,
#                                               rms );
#
# overlaps->GetXaxis()->SetTitle( "Outputted SNR" );
# overlaps->GetXaxis()->CenterTitle();
# overlaps->GetYaxis()->SetTitle( "averge overlap" );
# overlaps->GetYaxis()->CenterTitle();
# overlaps->SetTitle("Overlaps distribution");
# overlaps->SetMarkerStyle(104);
#
# double    SNR1[nBinDx];
# double errSNR1[nBinDx]; //HA ERRORE L'SNR RICOSTRUITO?
# double    mea1[nBinDx];
# double    err1[nBinDx];
# for( int i = 0; i < nBinDx; ++i ){
#     SNR1[i]    =          1 / SNR[i];
#     mea1[i]    =          1 / mea[i];
#     err1[i]    =     err[i] / ( mea[i] * mea[i] );
#     errSNR1[i] = errSNR1[i] / ( SNR[i] * SNR[i] );
# }
#
# TGraphErrors *overlaps1 = new TGraphErrors( nBinDx,
#                                               SNR1,
#                                               mea1,
#                                            errSNR1,
#                                               err1 );
# overlaps1->GetXaxis()->SetTitle( "(Outputted SNR)^{-1}" );
# overlaps1->GetXaxis()->CenterTitle();
# overlaps1->GetYaxis()->SetTitle( "(averge overlap)^{-1}" );
# overlaps1->GetYaxis()->CenterTitle();
# overlaps1->SetTitle("Overlaps distribution");
# overlaps1->SetMarkerStyle(104);
#
# TF1 *line = new TF1( "line", "[0] * x + 1", 0, 1000000 );
# TFitResultPtr r = overlaps1->Fit(line, "RS");
# gStyle -> SetOptFit();
#
# double  A = line -> GetParameter( 0 );
# double eA = line ->  GetParError( 0 );
# std::cout << "A:\t "                               <<   A
#           << "\t +/- \t"                           <<  eA
#           << "\t \t \t "
#           << round( fabs( eA / A * 10000 ) ) / 100 << "%"
#           << std::endl;
# // to access the covariance matrix
# TMatrixDSym  cov = r->GetCovarianceMatrix();
# // to retrieve the fit chi2
# double      chi2 = r->Chi2();
# // to retrieve the fit rho
# double       rho = overlaps1->GetCorrelationFactor();
#
# std::cout << "\nCOVARIANCE MATRIX :\n ";
# cov.Print();
#
# gStyle->SetStatX(0.45);
# gStyle->SetStatY(0.925);
# std::cout << "chi2:\t\t"  << chi2 << std::endl;
# std::cout << "rho:\t\t"   << rho  << std::endl;
# TCanvas  *ct11 = new TCanvas( "ct11", "ct11", 1200, 1000 );
# ct11->cd();
# overlaps1->Draw("AP");
# ct11->Draw();
# ct11->Print(("report/overlapDistributions_Fit.pdf"));
# Out:
#  FCN=143.426 FROM MIGRAD    STATUS=CONVERGED      14 CALLS          15 TOTAL
#                      EDM=3.26838e-16    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.39983e+00   1.72037e-02   1.20485e-04   1.48614e-06
# A:	 1.39983	 +/- 	0.0172037	 	 	 1.23%
#
# COVARIANCE MATRIX :
#
# 1x1 matrix is as follows
#
#      |      0    |
# ------------------
#    0 |   0.000296
#
# chi2:		143.426
# rho:		0.996095
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/overlapDistributions_Fit.pdf has been created

# %% [markdown]
# due cose al volo, poi controllo stasera con più calma:
# 1) si indicherei la std deviation del la dsitribuzione, perchè questo statisticamente ti indica la "larghezza" della distribuzione e quindi di quanto varia quel valore, quant'è larga la distribuzione. L'errore della media ti da l'errore nella stima della media,. Ma credo sia più interessante vedere la std deviation
#
#
# 2) per verificare cosa sono quegli eventi nella macchia, prova a cercare a che job appartengono. Quindi vai a vedere se hanno qualcosa di "speciale" nei valori. E infine prova fare i ced solo di uno di quei job che hai selezionato e che danno quel valoro strano. Non sono sicura che tu possa riprodurre esattamente  quelle simulaizoni; perchè la posizione del cielo è random, e il seed dipende dal job, e da dove lo runni temo. Potresti aver risultati diversi. Ma trova il job, e vedi che succede. Se hai risultati diversi proverò io a runnare quello specifico job

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_APR4_q09.M1_cl.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, oSNR, iSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
#
# std::vector <TH1F*> VoSNR;
# VoSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 300 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j ){
#             VoSNR[j-1]->Fill( sqrt(oSNR) );
# //            std::cout << oSNR[0] << " " << oSNR[1] << " " << oSNR[2] << std::endl;
#         }
# }
#
# std::vector <TH1F*> ViSNR;
# ViSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 300 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             ViSNR[j-1]->Fill( sqrt(iSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1080, 1920 );
# ct9->Divide(1,2);
# ct9->cd(1);
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ViSNR[i-1]->Draw("SAME");
#     ViSNR[i-1]->SetLineWidth(4);
# }
#
# ViSNR[0]->SetLineColor(kBlue);
# ViSNR[1]->SetLineColor(kRed);
# ViSNR[2]->SetLineColor(kGreen);
# ViSNR[3]->SetLineColor(kBlack);
# ViSNR[4]->SetLineColor(kViolet);
#
# ViSNR[0]->            SetTitle( "Injected" );
# ViSNR[0]->GetXaxis()->SetTitle(   "iSNR"   );
# ViSNR[0]->GetYaxis()->SetTitle(  "counts"  );
#
# ViSNR[0]->GetXaxis()->CenterTitle();
# ViSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendiSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendiSNR->SetHeader("Distances", "C");
# legendiSNR->SetNColumns(2);
#
# const char* legNameiSNR;
# string lNameiSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameiSNR   = d[i] + " kPc";
#     legNameiSNR = lNameiSNR.c_str();
#     legendiSNR->AddEntry( ViSNR[i], legNameiSNR, "l" );
# }
#
# legendiSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
#
# ct9->cd(2);
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     VoSNR[i-1]->Draw("SAME");
#     VoSNR[i-1]->SetLineWidth(4);
# }
#
# gStyle -> SetOptStat(0);
#
# VoSNR[0]->SetLineColor(kBlue);
# VoSNR[1]->SetLineColor(kRed);
# VoSNR[2]->SetLineColor(kGreen);
# VoSNR[3]->SetLineColor(kBlack);
# VoSNR[4]->SetLineColor(kViolet);
#
# VoSNR[0]->            SetTitle( "Outputted" );
# VoSNR[0]->GetXaxis()->SetTitle(   "oSNR"    );
# VoSNR[0]->GetYaxis()->SetTitle(  "counts"   );
#
# VoSNR[0]->GetXaxis()->CenterTitle();
# VoSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendoSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendoSNR->SetHeader("Distances", "C");
# legendoSNR->SetNColumns(2);
#
#
# const char* legNameoSNR;
# string lNameoSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameoSNR   = d[i] + " kPc";
#     legNameoSNR = lNameoSNR.c_str();
#     legendoSNR->AddEntry( VoSNR[i], legNameoSNR, "l" );
# }
#
# legendoSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("report/APR4_SNRDistributionFactors.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 16197 not found at 102
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TFile::Append>: Replacing existing TH1: distance1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance4 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance5 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/APR4_SNRDistributionFactors.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(111111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 4*16;
# int nBinDy = 4*75;
# float iSNR, oSNR;
# float ioSNR[3];
# const char* hName;
# std::string histname;
# double time[6];
#
# merge_tree->SetBranchAddress(   "time", &time   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# TH2F* Voverlap = new TH2F( "Voverlap", "Voverlap",
#                            nBinDx,  0,        250,
#                            nBinDy,  0,          1 );
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "Distance = " +  d[i] + " kPc";
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName,   hName,
#                                nBinDx, 0, 250,
#                                nBinDy, 0,   1));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     if( abs( time[0] - time[3] ) < 5 ){
#         Voverlap->Fill(          sqrt(   iSNR    ),
#                         ioSNR[1] /  sqrt( iSNR*oSNR ));
#         for( int j = 1; j < 6; ++j )
#             if( factor == j )
#                 VioSNR[j-1]->Fill(         sqrt(   iSNR    ),
#                                    ioSNR[1] / sqrt( iSNR*oSNR ));
#     }
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.4);
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
# //    gPad->SetGrid();
#     VioSNR[i-1]->SetMarkerSize(10);
#     VioSNR[i-1]->Draw("");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle( "Injected SNR" );
#     VioSNR[i]->GetYaxis()->SetTitle(    "overlap"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("report/overlapDistributionFactor.pdf"));
#
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1200, 1000 );
# ct10->cd();
# //gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.92);
# gStyle->SetStatY(0.4);
# Voverlap->Draw("");
# Voverlap->SetLineWidth(4);
# Voverlap->SetLineColor(kBlue);
# Voverlap->            SetTitle( "Overlap distribution" );
# Voverlap->GetXaxis()->SetTitle( "Injected SNR" );
# Voverlap->GetYaxis()->SetTitle(    "overlap"   );
# Voverlap->GetXaxis()->CenterTitle();
# Voverlap->GetYaxis()->CenterTitle();
#
# ct10->Draw();
# ct10->Print(("report/overlapDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file report/overlapDistributionFactor.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct10
# Info in <TCanvas::Print>: pdf file report/overlapDistribution.pdf has been created
