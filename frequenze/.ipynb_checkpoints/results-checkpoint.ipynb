# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.22/02

# %%
# %%cpp
# TFile *results = new TFile("wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root", "update");
# Out:
# Warning in <TClass::Init>: no dictionary for class detectorParams is available

# %%
# %%cpp
# results->cd();
# waveburst->Print();
# Out:
# ******************************************************************************
# *Tree    :waveburst : waveburst                                              *
# *Entries :     4377 : Total =         2509636 bytes  File  Size =    2016372 *
# *        :          : Tree compression factor =   1.20                       *
# ******************************************************************************
# *Br    0 :run       : run/I                                                  *
# *Entries :     4377 : Total  Size=      35950 bytes  File Size  =      25888 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.23     *
# *............................................................................*
# *Br    1 :eventID   : eventID[2]/I                                           *
# *Entries :     4377 : Total  Size=      54244 bytes  File Size  =      23680 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.12     *
# *............................................................................*
# *Br    2 :strain    : strain[2]/D                                            *
# *Entries :     4377 : Total  Size=      89073 bytes  File Size  =      84930 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    3 :phi       : phi[4]/F                                               *
# *Entries :     4377 : Total  Size=      88480 bytes  File Size  =      77489 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.09     *
# *............................................................................*
# *Br    4 :theta     : theta[4]/F                                             *
# *Entries :     4377 : Total  Size=      88870 bytes  File Size  =      78070 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.09     *
# *............................................................................*
# *Br    5 :psi       : psi[2]/F                                               *
# *Entries :     4377 : Total  Size=      53464 bytes  File Size  =      41044 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    6 :iota      : iota[2]/F                                              *
# *Entries :     4377 : Total  Size=      53659 bytes  File Size  =      42339 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.17     *
# *............................................................................*
# *Br    7 :time      : time[6]/D                                              *
# *Entries :     4377 : Total  Size=     228747 bytes  File Size  =     136624 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   1.64     *
# *............................................................................*
# *Br    8 :duration  : duration[3]/F                                          *
# *Entries :     4377 : Total  Size=      71947 bytes  File Size  =      49264 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.38     *
# *............................................................................*
# *Br    9 :frequency : frequency[3]/F                                         *
# *Entries :     4377 : Total  Size=      72142 bytes  File Size  =      56878 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   10 :low       : low[3]/F                                               *
# *Entries :     4377 : Total  Size=      70972 bytes  File Size  =      23289 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.87     *
# *............................................................................*
# *Br   11 :high      : high[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      32477 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   2.06     *
# *............................................................................*
# *Br   12 :bandwidth : bandwidth[3]/F                                         *
# *Entries :     4377 : Total  Size=      72142 bytes  File Size  =      52077 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.31     *
# *............................................................................*
# *Br   13 :hrss      : hrss[6]/D                                              *
# *Entries :     4377 : Total  Size=     228747 bytes  File Size  =     224546 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   14 :noise     : noise[3]/D                                             *
# *Entries :     4377 : Total  Size=     123894 bytes  File Size  =     119755 *
# *Baskets :      191 : Basket Size=       1024 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   15 :erA       : erA[11]/F                                              *
# *Entries :     4377 : Total  Size=     211038 bytes  File Size  =      96776 *
# *Baskets :      191 : Basket Size=       1536 bytes  Compression=   2.14     *
# *............................................................................*
# *Br   16 :null      : null[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   17 :nill      : nill[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   18 :netcc     : netcc[4]/F                                             *
# *Entries :     4377 : Total  Size=      88870 bytes  File Size  =      83135 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.02     *
# *............................................................................*
# *Br   19 :rho       : rho[2]/F                                               *
# *Entries :     4377 : Total  Size=      53464 bytes  File Size  =      49341 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   20 :gnet      : gnet/F                                                 *
# *Entries :     4377 : Total  Size=      36145 bytes  File Size  =      32024 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   21 :ecor      : ecor/F                                                 *
# *Entries :     4377 : Total  Size=      36145 bytes  File Size  =      32024 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   22 :penalty   : penalty/F                                              *
# *Entries :     4377 : Total  Size=      36730 bytes  File Size  =      32597 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   23 :likelihood : likelihood/F                                          *
# *Entries :     4377 : Total  Size=      37315 bytes  File Size  =      33170 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   24 :factor    : factor/F                                               *
# *Entries :     4377 : Total  Size=      36535 bytes  File Size  =      20528 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.58     *
# *............................................................................*
# *Br   25 :snr       : snr[3]/F                                               *
# *Entries :     4377 : Total  Size=      70972 bytes  File Size  =      66849 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   26 :xSNR      : xSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   27 :sSNR      : sSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   28 :iSNR      : iSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   29 :oSNR      : oSNR[3]/F                                              *
# *Entries :     4377 : Total  Size=      71167 bytes  File Size  =      67040 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   30 :ioSNR     : ioSNR[3]/F                                             *
# *Entries :     4377 : Total  Size=      71362 bytes  File Size  =      67231 *
# *Baskets :      191 : Basket Size=        512 bytes  Compression=   1.00     *
# *............................................................................*
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0

# %%
# %%cpp
# TCanvas *ct = new TCanvas( "ct", "ct", 600, 600 );
# ct->cd();
# waveburst->Draw("oSNR");
# ct->Draw();

# %%
# %%cpp
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path +    "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TH1F* hist_rho = new TH1F( "hist_rho", "hist_rho", 100, 0, 150 );
# TH2F* hist_rho_time[num_det];
#
# char cuts[4096];
# char name[1028];
# char  sel[1028];
#
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
#
# for( int jj=0; jj<num_det; jj++ ){ // ciclo sui rivelatori
#     cx[jj]->cd();
#     sprintf( cuts, "rho<250" );
#     merge_tree->Draw( "rho>>hist_rho", cuts);
#
#     sprintf( name, "hist_rho_time_%i", jj );
#     hist_rho_time[jj] = new TH2F( name,  name, 1000, 1.1645e+9,
#                                       1.1651*1e+9,  100, 0,   250);
#     sprintf( sel, "rho:time[%i]>>hist_rho_time_%i", jj, jj );
#     merge_tree->Draw( sel, cuts );
#     cx[jj]->Draw("COL");
# }
#
# int            entr = merge_tree->GetEntries();
# const auto det_cons =		 2 * 	 num_det;
# double time[det_cons];
# float rho;
#
# merge_tree->SetBranchAddress( "time", &time );
# merge_tree->SetBranchAddress(  "rho", &rho  );
#
# for( int i=0; i < entr; i++ ){
#     merge_tree->GetEntry( i );
# //    cout << time[0] << "\t" << rho << endl;
# }
#
# TCanvas* Cplot = new TCanvas( "plot", "plot", 600,
#                                400,    600, 400);
# Cplot->Divide( 2, 1 );
# Cplot->cd(        1 );
#
# hist_rho->Draw();
# Cplot->cd(2);
# hist_rho_time[0]->Draw();
# char out[1024];
#
# Cplot->Draw();
#
#
# sprintf( out, "%s/test_rho.png", path_save.Data() );
# Cplot->SaveAs( out );
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Info in <TCanvas::Print>: png file /home/aidin/Documenti/Tesi/analisi/frequenze/report/dump/test_rho.png has been created

# %%
# %%cpp
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TH1F* hist_oSNR = new TH1F( "hist_oSNR", "hist_oSNR", 75, 0, 260 );
# TH2F* hist_oSNR_time[num_det];
#
# char cuts[4096];
# char name[1028];
# char  sel[1028];
#
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
#
# for( int jj=0; jj<num_det; jj++ ){ // ciclo sui rivelatori
#     cx[jj]->cd();
#     sprintf( cuts, "oSNR<250" );
#     merge_tree->Draw( "oSNR>>hist_oSNR", cuts);
#
#     sprintf( name, "hist_oSNR_time_%i", jj );
#     hist_oSNR_time[jj] = new TH2F( name,  name, 500, 1.1645e+9,
#                                       1.1651*1e+9,  75, 0,   260);
#     sprintf( sel, "oSNR:time[%i]>>hist_oSNR_time_%i", jj, jj );
#     merge_tree->Draw( sel, cuts );
#     cx[jj]->Draw("COL");
# }
#
# int            entr = merge_tree->GetEntries();
# const auto det_cons =		 2 * 	 num_det;
# double time[det_cons];
# float oSNR;
#
# merge_tree->SetBranchAddress( "time", &time );
# merge_tree->SetBranchAddress( "oSNR", &oSNR  );
#
# for( int i=0; i < entr; i++ ){
#     merge_tree->GetEntry( i );
# //    cout << time[0] << "\t" << oSNR << endl;
# }
#
# TCanvas* Cplot = new TCanvas( "plot", "plot", 600,
#                                400,    600, 400);
# Cplot->Divide( 2, 1 );
# Cplot->cd(        1 );
#
# hist_oSNR->Draw();
# Cplot->cd(2);
# hist_oSNR_time[0]->Draw();
# char out[1024];
#
# Cplot->Draw();
#
#
# sprintf( out, "%s/test_oSNR.png", path_save.Data() );
# Cplot->SaveAs( out );
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: plot
# Info in <TCanvas::Print>: png file /home/aidin/Documenti/Tesi/analisi/frequenze/report/dump/test_oSNR.png has been created

# %%
# %%cpp
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TH1F* hist_iSNR = new TH1F( "hist_iSNR", "hist_iSNR", 75, 0, 260 );
# TH2F* hist_iSNR_time[num_det];
#
# char cuts[4096];
# char name[1028];
# char  sel[1028];
# /*
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
# */
# TCanvas* cx = new TCanvas( "c", "c", 500, 500 );
# cx->cd();
# for( int jj=0; jj<num_det; jj++ ){ // ciclo sui rivelatori
# //    cx[jj]->cd();
#     sprintf( cuts, "iSNR<250" );
#     merge_tree->Draw( "iSNR>>hist_iSNR", cuts);
#
#     sprintf( name, "hist_iSNR_time_%i", jj );
#     hist_iSNR_time[jj] = new TH2F( name,  name, 500, 1.1645e+9,
#                                       1.1651*1e+9,  75, 0,   260);
#     sprintf( sel, "iSNR:time[%i]>>hist_iSNR_time_%i", jj, jj );
#     merge_tree->Draw( sel, cuts );
#
# //    cx[jj]->Draw("COLZ");
#     cx->Draw();
# }
#
# int            entr = merge_tree->GetEntries();
# const auto det_cons =		 2 * 	 num_det;
# //double time[det_cons];
# double time;
# float iSNR;
#
# merge_tree->SetBranchAddress( "time", &time );
# merge_tree->SetBranchAddress( "iSNR", &iSNR  );
#
# for( int i=0; i < entr; i++ ){
#     merge_tree->GetEntry( i );
# //    cout << time[0] << "\t" << time[1] << "\t" << time[5] << endl;
# }
#
# TCanvas* Cplot = new TCanvas( "plot", "plot", 600,
#                                400,    600, 400);
# Cplot->Divide( 2, 1 );
# Cplot->cd(        1 );
#
# hist_iSNR->Draw();
# Cplot->cd(2);
# hist_iSNR_time[0]->Draw();
# char out[1024];
#
# Cplot->Draw();
#
#
# sprintf( out, "%s/test_iSNR.png", path_save.Data() );
# Cplot->SaveAs( out );
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: plot
# Info in <TCanvas::Print>: png file /home/aidin/Documenti/Tesi/analisi/frequenze/report/dump/test_iSNR.png has been created

# %%
# %%cpp
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TH1F* hist_ioSNR = new TH1F( "hist_ioSNR", "hist_ioSNR", 75, 0, 260 );
# TH2F* hist_ioSNR_time[num_det];
#
# char cuts[4096];
# char name[1028];
# char  sel[1028];
#
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
#
# for( int jj=0; jj<num_det; jj++ ){ // ciclo sui rivelatori
#     cx[jj]->cd();
#     sprintf( cuts, "ioSNR<250" );
#     merge_tree->Draw( "ioSNR>>hist_ioSNR", cuts);
#
#     sprintf( name, "hist_ioSNR_time_%i", jj );
#     hist_ioSNR_time[jj] = new TH2F( name,  name, 500, 1.1645e+9,
#                                       1.1651*1e+9,  75, 0,   260);
#     sprintf( sel, "ioSNR:time[%i]>>hist_ioSNR_time_%i", jj, jj );
#     merge_tree->Draw( sel, cuts );
#     cx[jj]->Draw("COL");
# }
#
# int            entr = merge_tree->GetEntries();
# const auto det_cons =		 2 * 	 num_det;
# double time[det_cons];
# float ioSNR;
#
# merge_tree->SetBranchAddress( "time", &time );
# merge_tree->SetBranchAddress( "ioSNR", &ioSNR  );
#
# for( int i=0; i < entr; i++ ){
#     merge_tree->GetEntry( i );
# //    cout << time[0] << "\t" << ioSNR << endl;
# }
#
# TCanvas* Cplot = new TCanvas( "plot", "plot", 600,
#                                400,    600, 400);
# Cplot->Divide( 2, 1 );
# Cplot->cd(        1 );
#
# hist_ioSNR->Draw();
# Cplot->cd(2);
# hist_ioSNR_time[0]->Draw();
# char out[1024];
#
# Cplot->Draw();
#
#
# sprintf( out, "%s/test_ioSNR.png", path_save.Data() );
# Cplot->SaveAs( out );
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: plot
# Info in <TCanvas::Print>: png file /home/aidin/Documenti/Tesi/analisi/frequenze/report/dump/test_ioSNR.png has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# int numDistances = 5;
# int nBinDx = 10;
# int nBinDy = 10;
# float factor, ioSNR, iSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
#
# /*
# TCanvas** cx = new TCanvas*[num_det];
# std::string namestr;
# const char* namecanvas;
# for( int j = 0; j < num_det; ++j ){
#     namestr = "c" + std::to_string(j);
#     namecanvas = namestr.c_str();
#     cx[j] = new TCanvas( namecanvas, namecanvas, 400, 400 );
# }
# */
#
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance_" + std::to_string( i  + 1 );
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName, hName,
#                          nBinDx, 0, 250,
#                          nBinDy, 0, 250  ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR[j-1]->Fill( sqrt(iSNR), sqrt(ioSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# //ct9->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
#     VioSNR[i-1]->Draw("SAME COLZ");
# //    VioSNR[i-1]->SetLineWidth(4);
# }
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(   "iSNR"     );
#     VioSNR[i]->GetYaxis()->SetTitle(  "ioSNR"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
#
# ct9->Draw();
# ct9->Print(("ioSNRDistributionFactor.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Info in <TCanvas::Print>: pdf file ioSNRDistributionFactor.pdf has been created

# %%
# %%cpp
#
# TH2F *hframeSNR = new TH2F("hframeSNR","hframeSNR",400,0,5.5,400,0,620);
# hframeSNR->Draw();
#
# const int num_det = 3;
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# TCanvas *kp1bs= new TCanvas("kp1bs", "kp1bs", 600,600);
# kp1bs->cd();
# merge_tree->Draw("sqrt(ioSNR):sqrt(iSNR)");
# kp1bs->Draw();
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle->SetOptStat(0);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, iSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR    );
#
# std::vector <TH1F*> ViSNR;
# ViSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             ViSNR[j-1]->Fill( sqrt(iSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# ct9->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ViSNR[i-1]->Draw("SAME");
#     ViSNR[i-1]->SetLineWidth(4);
# }
#
# ViSNR[0]->SetLineColor(kBlue);
# ViSNR[1]->SetLineColor(kRed);
# ViSNR[2]->SetLineColor(kGreen);
# ViSNR[3]->SetLineColor(kBlack);
# ViSNR[4]->SetLineColor(kViolet);
#
# ViSNR[0]->            SetTitle(  "iSNR"  );
# ViSNR[0]->GetXaxis()->SetTitle(  "iSNR"  );
# ViSNR[0]->GetYaxis()->SetTitle( "counts" );
#
# ViSNR[0]->GetXaxis()->CenterTitle();
# ViSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legend = new TLegend(0.75,0.6,0.925,0.925);
# legend->SetHeader("Distances", "C");
#
#
# const char* legName;
# std:string lName;
# for( int i = 0; i < numDistances; ++i ){
#     lName   = d[i] + " kPc";
#     legName = lName.c_str();
#     legend->AddEntry( ViSNR[i], legName, "l" );
# }
#
# legend->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("iSNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file iSNRDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(0);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, oSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR    );
#
# std::vector <TH1F*> VoSNR;
# VoSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VoSNR[j-1]->Fill( sqrt(oSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# ct9->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     VoSNR[i-1]->Draw("SAME");
#     VoSNR[i-1]->SetLineWidth(4);
# }
#
# VoSNR[0]->SetLineColor(kBlue);
# VoSNR[1]->SetLineColor(kRed);
# VoSNR[2]->SetLineColor(kGreen);
# VoSNR[3]->SetLineColor(kBlack);
# VoSNR[4]->SetLineColor(kViolet);
#
# VoSNR[0]->            SetTitle(  "oSNR"  );
# VoSNR[0]->GetXaxis()->SetTitle(  "oSNR"  );
# VoSNR[0]->GetYaxis()->SetTitle( "counts" );
#
# VoSNR[0]->GetXaxis()->CenterTitle();
# VoSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legend = new TLegend(0.75,0.6,0.925,0.925);
# legend->SetHeader("Distances", "C");
#
#
# const char* legName;
# std:string lName;
# for( int i = 0; i < numDistances; ++i ){
#     lName   = d[i] + " kPc";
#     legName = lName.c_str();
#     legend->AddEntry( VoSNR[i], legName, "l" );
# }
#
# legend->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("oSNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file oSNRDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinD = 150;
# float iSNR, oSNR;
#
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
#
# TH1F* ViSNR = new TH1F( "Injected", "Injected", nBinD, 0, 250 );
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     ViSNR->Fill( sqrt(iSNR) );
# }
#
# TH1F* VoSNR = new TH1F( "Outputted", "Outputted", nBinD, 0, 250 );
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     VoSNR->Fill( sqrt(oSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1080, 1920 );
# ct9->Divide(1,2);
# ct9->cd(1);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
#
# ViSNR->Draw("SAME");
# ViSNR->SetLineWidth(4);
# ViSNR->SetLineColor(kBlue);
# ViSNR->            SetTitle( "Injected" );
# ViSNR->GetXaxis()->SetTitle(   "iSNR"   );
# ViSNR->GetYaxis()->SetTitle(  "counts"  );
# ViSNR->GetXaxis()->CenterTitle();
# ViSNR->GetYaxis()->CenterTitle();
#
# ct9->cd(2);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# VoSNR->Draw("SAME");
# VoSNR->SetLineWidth(4);
# VoSNR->SetLineColor(kBlue);
# VoSNR->            SetTitle( "Outputted" );
# VoSNR->GetXaxis()->SetTitle(   "oSNR"    );
# VoSNR->GetYaxis()->SetTitle(  "counts"   );
# VoSNR->GetXaxis()->CenterTitle();
# VoSNR->GetYaxis()->CenterTitle();
#
#
# ct9->Draw();
# ct9->Print(("SNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file SNRDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
#
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, oSNR;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
#
# std::vector <TH1F*> VoSNR;
# VoSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VoSNR[j-1]->Fill( sqrt(oSNR) );
# }
#
# std::vector <TH1F*> ViSNR;
# ViSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             ViSNR[j-1]->Fill( sqrt(iSNR) );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1080, 1920 );
# ct9->Divide(1,2);
# ct9->cd(1);
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ViSNR[i-1]->Draw("SAME");
#     ViSNR[i-1]->SetLineWidth(4);
# }
#
# ViSNR[0]->SetLineColor(kBlue);
# ViSNR[1]->SetLineColor(kRed);
# ViSNR[2]->SetLineColor(kGreen);
# ViSNR[3]->SetLineColor(kBlack);
# ViSNR[4]->SetLineColor(kViolet);
#
# ViSNR[0]->            SetTitle( "Injected" );
# ViSNR[0]->GetXaxis()->SetTitle(   "iSNR"   );
# ViSNR[0]->GetYaxis()->SetTitle(  "counts"  );
#
# ViSNR[0]->GetXaxis()->CenterTitle();
# ViSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendiSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendiSNR->SetHeader("Distances", "C");
# legendiSNR->SetNColumns(2);
#
# const char* legNameiSNR;
# string lNameiSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameiSNR   = d[i] + " kPc";
#     legNameiSNR = lNameiSNR.c_str();
#     legendiSNR->AddEntry( ViSNR[i], legNameiSNR, "l" );
# }
#
# legendiSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
#
# ct9->cd(2);
# gPad->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     VoSNR[i-1]->Draw("SAME");
#     VoSNR[i-1]->SetLineWidth(4);
# }
#
# gStyle -> SetOptStat(0);
#
# VoSNR[0]->SetLineColor(kBlue);
# VoSNR[1]->SetLineColor(kRed);
# VoSNR[2]->SetLineColor(kGreen);
# VoSNR[3]->SetLineColor(kBlack);
# VoSNR[4]->SetLineColor(kViolet);
#
# VoSNR[0]->            SetTitle( "Outputted" );
# VoSNR[0]->GetXaxis()->SetTitle(   "oSNR"    );
# VoSNR[0]->GetYaxis()->SetTitle(  "counts"   );
#
# VoSNR[0]->GetXaxis()->CenterTitle();
# VoSNR[0]->GetYaxis()->CenterTitle();
#
# TLegend *legendoSNR = new TLegend(0.725,0.8,0.95,0.925);
# legendoSNR->SetHeader("Distances", "C");
# legendoSNR->SetNColumns(2);
#
#
# const char* legNameoSNR;
# string lNameoSNR;
# for( int i = 0; i < numDistances; ++i ){
#     lNameoSNR   = d[i] + " kPc";
#     legNameoSNR = lNameoSNR.c_str();
#     legendoSNR->AddEntry( VoSNR[i], legNameoSNR, "l" );
# }
#
# legendoSNR->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct9->Draw();
# ct9->Print(("SNRDistributionFactors.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TFile::Append>: Replacing existing TH1: distance1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance4 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance5 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file SNRDistributionFactors.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 16;
# int nBinDy = 50;
# float iSNR, oSNR, factor;
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
#
# TH2F* VioSNR = new TH2F( "Residual", "Residual",
#                          nBinDx,  0,        400,
#                          nBinDy,  0,        1.6 );
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     VioSNR->Fill( sqrt(                 iSNR ),
#                   sqrt( iSNR * oSNR ) / iSNR );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.25);
# gStyle->SetStatY(0.25);
# VioSNR->Draw("COLZ");
# VioSNR->SetLineWidth(4);
# VioSNR->SetLineColor(kBlue);
# VioSNR->            SetTitle( "" );
# VioSNR->GetXaxis()->SetTitle(   "iSNR"   );
# VioSNR->GetYaxis()->SetTitle(  "iSNR*oSNR/iSNR^2"  );
# VioSNR->GetXaxis()->CenterTitle();
# VioSNR->GetYaxis()->CenterTitle();
#
# ct9->Draw();
# ct9->Print(("i*oSNRDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file i*oSNRDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 16;
# int nBinDy = 50;
# float ioSNR, iSNR, oSNR, factor;
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
#
# TH2F* VioSNR = new TH2F( "VioSNR", "VioSNR",
#                          nBinDx,  0,        400,
#                          nBinDy,  0,          2 );
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     VioSNR->Fill(                     sqrt( iSNR ),
#                   abs(iSNR + oSNR - 2*ioSNR) / iSNR );
#     std::cout <<  (iSNR + oSNR - 2*ioSNR) / iSNR << std::endl;
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.85);
# gStyle->SetStatY(0.95);
# VioSNR->Draw("COLZ");
# VioSNR->SetLineWidth(4);
# VioSNR->SetLineColor(kBlue);
# VioSNR->            SetTitle( "" );
# VioSNR->GetXaxis()->SetTitle(   "iSNR"   );
# VioSNR->GetYaxis()->SetTitle(  "|iSNR-oSNR|/iSNR"  );
# VioSNR->GetXaxis()->CenterTitle();
# VioSNR->GetYaxis()->CenterTitle();
#
# ct9->Draw();
# ct9->Print(("i-oSNRDistribution.pdf"));
# Out:
# 36.701
# -0.677419
# -0.716183
# 0.61324
# -3.3366
# -5.66353
# -0.236438
# 0.378832
# 0.696886
# 5.09155
# -0.521732
# -4.64989
# 0.656392
# 1.1073
# -0.983049
# -0.288023
# 0.624633
# 1.97925
# -0.542507
# -1.54301
# 3.32276
# -0.24212
# -0.829695
# -1.91384
# 1.09326
# 6.73504
# -3.52074
# -1.22162
# -1.27818
# -3.48317
# 28.6814
# 3.02216
# 0.289339
# 701.389
# -0.949407
# 1.01758
# 3.58494
# -1.17251
# 0.356089
# -3.83978
# 0.529668
# 0.115512
# 9.73541
# -0.392363
# 0.925714
# -1.14273
# -1.4942
# 2.32694
# 0.0259677
# 0.437204
# 0.31706
# 1.59163
# 3.95226
# -1.07325
# 1.39745
# -1.21786
# -1.12483
# 0.55868
# 1.17884
# -0.0532097
# 0.097604
# 0.95018
# 110.568
# -1.70627
# 1.20307
# 0.193361
# 4.58356
# 76.0534
# -0.869884
# 9.30733
# 3.20268
# -4.21227
# 0.274533
# 5.12951
# -1.47903
# 1.04129
# -3.78381
# 0.241853
# 4.79556
# 2.90266
# 0.525395
# -1.01812
# -2.68666
# 0.396358
# -1.25145
# -3.74974
# -5.15832
# 1.6008
# 9.14533
# 3.61907
# -0.673392
# 0.49997
# -6.51546
# -0.231438
# 1.11229
# 1.0179
# 2.9182
# -1.11036
# -4.43716
# 0.831412
# -2.39425
# -1.21656
# -3.64652
# 0.487455
# 3.05663
# 1.86051
# 13.8287
# 0.0772626
# 0.165409
# -2.35319
# -0.810585
# -0.0729685
# -1.9924
# 35.2089
# 0.176256
# 0.0864854
# 14.1489
# 0.141036
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file i-oSNRDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 16;
# int nBinDy = 75;
# float iSNR, oSNR, ioSNR;
# const char* hName;
# std::string histname;
#
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName, hName,
#                               nBinDx, 0, 400,
#                               nBinDy, 0, 1.5));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR[j-1]->Fill(                          sqrt( iSNR ),
#                                abs( iSNR + oSNR - 2*ioSNR ) /  iSNR );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
#
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
#     VioSNR[i-1]->Draw("SAME COLZ");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(   "sqrt(iSNR)"     );
#     VioSNR[i]->GetYaxis()->SetTitle(  "(iSNR+oSNR-2ioSNR)/iSNR"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("i-oSNRDistributionFactor.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file i-oSNRDistributionFactor.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# //int nBinDx = 16;
# int nBinDx = 50;
# int nBinDy = 50;
# float iSNR, oSNR;
# const char* hName;
# std::string histname;
# float likelihood, factor;
#
# merge_tree->SetBranchAddress(       "iSNR", &iSNR       );
# merge_tree->SetBranchAddress(       "oSNR", &oSNR       );
# merge_tree->SetBranchAddress(      "ioSNR", &ioSNR      );
# merge_tree->SetBranchAddress(     "factor", &factor     );
# merge_tree->SetBranchAddress( "likelihood", &likelihood );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName, hName,
#                               nBinDx, 0, 150000,
#                               nBinDy, 0,   1));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
# //    std::cout << (iSNR + oSNR - 2*ioSNR)/iSNR << std::endl;
# //    std::cout << likelihood << std::endl;
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR[j-1]->Fill(                    likelihood,
#                              (iSNR + oSNR - 2*ioSNR)/iSNR);
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.75);
# gStyle->SetStatY(0.75);
#
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
#     VioSNR[i-1]->Draw("SAME COLZ");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(   "likelihood"     );
#     VioSNR[i]->GetYaxis()->SetTitle(  "|iSNR-oSNR|/iSNR"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# ct9->Print(("i-oSNRDistributionFactor.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file i-oSNRDistributionFactor.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle->SetOptStat(0);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int numDistances = 5;
# int nBinD = 100;
# float factor, likelihood;
# const char* hName;
# std::string histname;
# std::string d[5] = { "20000", "10000", "5000", "2500", "1250" };
#
# merge_tree->SetBranchAddress( "factor", &factor );
# merge_tree->SetBranchAddress(   "likelihood", &likelihood    );
#
# std::vector <TH1F*> Vlikelihood;
# Vlikelihood.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     Vlikelihood.push_back(new TH1F( hName, hName, nBinD, 0, 150000 ));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             Vlikelihood[j-1]->Fill( likelihood );
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->cd();
# ct9->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     Vlikelihood[i-1]->Draw("SAME");
#     Vlikelihood[i-1]->SetLineWidth(4);
# }
#
# Vlikelihood[0]->SetLineColor(kBlue);
# Vlikelihood[1]->SetLineColor(kRed);
# Vlikelihood[2]->SetLineColor(kGreen);
# Vlikelihood[3]->SetLineColor(kBlack);
# Vlikelihood[4]->SetLineColor(kViolet);
#
# Vlikelihood[0]->            SetTitle( "likelihood" );
# Vlikelihood[0]->GetXaxis()->SetTitle( "likelihood" );
# Vlikelihood[0]->GetYaxis()->SetTitle(   "counts"   );
#
# Vlikelihood[0]->GetXaxis()->CenterTitle();
# Vlikelihood[0]->GetYaxis()->CenterTitle();
# Vlikelihood[0]->SetMinimum(1);
#
# TLegend *legend = new TLegend(0.75,0.6,0.925,0.925);
# legend->SetHeader("Distances", "C");
#
#
# const char* legName;
# std:string lName;
# for( int i = 0; i < numDistances; ++i ){
#     lName   = d[i] + " kPc";
#     legName = lName.c_str();
#     legend->AddEntry( Vlikelihood[i], legName, "l" );
# }
#
# legend->Draw("SAME");
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
# //gPad->SetLogx();
#
# ct9->Draw();
# ct9->Print(("likelihoodDistribution.pdf"));
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Info in <TCanvas::Print>: pdf file likelihoodDistribution.pdf has been created

# %%
# %%cpp
#
# #include <string>
# #include <vector>
# gStyle -> SetOptStat(1111);
# TString path     = "/home/aidin/Documenti/Tesi/analisi/frequenze/";
# TString namefile = "wave_O4I_GN_LHV_SIM_PMNS_SHT2_0spin1_cl.M1.root";
#
# TString merge_file_name = path + namefile;
# TString       path_save = path + "report/dump";
#
# TFile*  filemerge = new TFile( merge_file_name.Data(), "update" );
# TTree* merge_tree =   ( TTree* )    filemerge->Get( "waveburst" );
#
# int nBinDx = 16;
# int nBinDy = 50;
# float iSNR, oSNR;
# const char* hName;
# std::string histname;
#
# merge_tree->SetBranchAddress(   "iSNR", &iSNR   );
# merge_tree->SetBranchAddress(   "oSNR", &oSNR   );
# merge_tree->SetBranchAddress(  "ioSNR", &ioSNR  );
# merge_tree->SetBranchAddress( "factor", &factor );
#
# std::vector <TH2F*> VioSNR;
# VioSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VioSNR.push_back(new TH2F( hName, hName,
#                               nBinDx, 0, 400,
#                               nBinDy, 0,   1));
# }
#
# int entr = merge_tree->GetEntries();
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
# //    std::cout << (iSNR + oSNR - 2*ioSNR)/iSNR << std::endl;
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR[j-1]->Fill(                sqrt(  iSNR   ),
#                              (iSNR + oSNR - 2*ioSNR)/iSNR);
# }
#
# TCanvas  *ct9 = new TCanvas( "ct9", "ct9", 1920, 1080 );
# ct9->Divide(3,2);
# gPad->SetGrid();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gStyle->SetStatX(0.5);
# gStyle->SetStatY(0.5);
#
#
#
# for( int i = 1; i < 6; ++i ){
#     ct9->cd(i);
#     VioSNR[i-1]->Draw("SAME COLZ");
# }
#
#
# for(int i = 0; i < numDistances; ++i){
#     VioSNR[i]->GetXaxis()->SetTitle(   "iSNR"     );
#     VioSNR[i]->GetYaxis()->SetTitle(  "|iSNR-oSNR|/iSNR"   );
#     VioSNR[i]->GetXaxis()->CenterTitle();
#     VioSNR[i]->GetYaxis()->CenterTitle();
# }
# ct9->Draw();
# //ct9->Print(("i-oSNRDistributionFactor.pdf"));
#
#
# std::vector <TH1F*> VoSNR;
# VoSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VoSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VoSNR[j-1]->Fill( sqrt(oSNR) );
# }
#
# TCanvas  *ct10 = new TCanvas( "ct10", "ct10", 1920, 1080 );
# ct10->cd();
# ct10->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     VoSNR[i-1]->Draw("SAME");
#     VoSNR[i-1]->SetLineWidth(4);
# }
#
# VoSNR[0]->SetLineColor(kBlue);
# VoSNR[1]->SetLineColor(kRed);
# VoSNR[2]->SetLineColor(kGreen);
# VoSNR[3]->SetLineColor(kBlack);
# VoSNR[4]->SetLineColor(kViolet);
#
# VoSNR[0]->            SetTitle(  "oSNR"  );
# VoSNR[0]->GetXaxis()->SetTitle(  "oSNR"  );
# VoSNR[0]->GetYaxis()->SetTitle( "counts" );
#
# VoSNR[0]->GetXaxis()->CenterTitle();
# VoSNR[0]->GetYaxis()->CenterTitle();
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct10->Draw();
#
#
# std::vector <TH1F*> ViSNR;
# ViSNR.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     ViSNR.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             ViSNR[j-1]->Fill( sqrt(iSNR) );
# }
#
# TCanvas  *ct11 = new TCanvas( "ct11", "ct11", 1920, 1080 );
# ct11->cd();
# ct11->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     ViSNR[i-1]->Draw("SAME");
#     ViSNR[i-1]->SetLineWidth(4);
# }
#
# ViSNR[0]->SetLineColor(kBlue);
# ViSNR[1]->SetLineColor(kRed);
# ViSNR[2]->SetLineColor(kGreen);
# ViSNR[3]->SetLineColor(kBlack);
# ViSNR[4]->SetLineColor(kViolet);
#
# ViSNR[0]->            SetTitle(  "iSNR"  );
# ViSNR[0]->GetXaxis()->SetTitle(  "iSNR"  );
# ViSNR[0]->GetYaxis()->SetTitle( "counts" );
#
# ViSNR[0]->GetXaxis()->CenterTitle();
# ViSNR[0]->GetYaxis()->CenterTitle();
#
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct11->Draw();
#
#
# std::vector <TH1F*> VioSNR1;
# VioSNR1.reserve( numDistances );
# for( int i = 0; i < numDistances; ++i ){
#     histname = "distance" + std::to_string(i+1);
#     hName = histname.c_str();
#     VioSNR1.push_back(new TH1F( hName, hName, nBinD, 0, 400 ));
# }
#
# for( int i = 0; i < entr; ++i ){
#     merge_tree->GetEntry( i );
#     for( int j = 1; j < 6; ++j )
#         if( factor == j )
#             VioSNR1[j-1]->Fill( sqrt(ioSNR) );
# }
#
# TCanvas  *ct12 = new TCanvas( "ct12", "ct12", 1920, 1080 );
# ct12->cd();
# ct12->SetGrid();
# for( int i = 1; i < 6; ++i ){
#     VioSNR1[i-1]->Draw("SAME");
#     VioSNR1[i-1]->SetLineWidth(4);
# }
#
# VioSNR1[0]->SetLineColor(kBlue);
# VioSNR1[1]->SetLineColor(kRed);
# VioSNR1[2]->SetLineColor(kGreen);
# VioSNR1[3]->SetLineColor(kBlack);
# VioSNR1[4]->SetLineColor(kViolet);
#
# VioSNR1[0]->            SetTitle(  "ioSNR"  );
# VioSNR1[0]->GetXaxis()->SetTitle(  "ioSNR"  );
# VioSNR1[0]->GetYaxis()->SetTitle( "counts" );
#
# VioSNR1[0]->GetXaxis()->CenterTitle();
# VioSNR1[0]->GetYaxis()->CenterTitle();
#
# gStyle->SetGridStyle(7);
# gStyle->SetGridWidth(1);
# gPad->SetLogy();
#
# ct12->Draw();
# Out:
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TClass::Load>: dictionary of class detector not found
# Error in <TExMap::Remove>: key 152413 not found at 4
# Warning in <TBufferFile::CheckObject>: reference to unavailable class TObject, pointers of this type will be 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct9
# Warning in <TFile::Append>: Replacing existing TH1: distance1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance4 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance5 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct10
# Warning in <TFile::Append>: Replacing existing TH1: distance1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance4 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance5 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct11
# Warning in <TFile::Append>: Replacing existing TH1: distance1 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance3 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance4 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: distance5 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ct12
